# %%
from bs4 import BeautifulSoup as soup
import requests
import urllib.request   
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
#Lectura de genes limpios(sin repetición)
df = pd.read_excel('Gen_abrev.xlsx',index_col=0, names=['N°','Gen abrev', 'Conteo'])
Datos = df["Gen abrev"]
datos= Datos.iloc[818:1636]
len(datos)
# Out:
# 818

# %%
lista_genes=[]
for i in range(len(datos)):
    lista_genes.append(datos.iloc[i])
lista_genes
# Out:
# ['MIR2426',
#  'PRKAG1',
#  'DDN',
#  'WNT10B',
#  'LOC112446681',
#  'ARF3',
#  'FKBP11',
#  'CCDC65',
#  'RND1',
#  'DDX23',
#  'CACNB3',
#  'ADCY6',
#  'TEX49',
#  'LOC107132475',
#  'CCNT1',
#  'KANSL2',
#  'LOC112446865',
#  'LOC112446866',
#  'MIR1291',
#  'LOC783895',
#  'LALBA',
#  'LOC104972406',
#  'LOC617415',
#  'LOC526630',
#  'LOC614370',
#  'LOC515887',
#  'OR8S27 LOC506992',
#  'OR8S25 LOC781446',
#  'OR8S10 LOC509508',
#  'LOC781517',
#  'OR8S15 LOC507383',
#  'LOC781595',
#  'OR8S1',
#  'OR8S24 LOC504567',
#  'LOC781756',
#  'LOC781840',
#  'LOC101907855',
#  'C5H12orf54',
#  'OR8S2 LOC509817',
#  'OR8S26 LOC781968',
#  'OR8S3 LOC617388',
#  'LOC617380',
#  'LOC518129',
#  'LOC100300010',
#  'OR5BJ2 LOC523258',
#  'LOC100848234',
#  'ZNF641',
#  'H1-7  LOC784038',
#  'H1FNT',
#  'LOC513452',
#  'LOC619137',
#  'LOC101902265',
#  'LOC101905376',
#  'LOC104972407',
#  'OR10AD1',
#  'CCDC184',
#  'LOC100139168',
#  'ASB8',
#  'PFKM',
#  'SENP1',
#  'COL2A1',
#  'TMEM106C',
#  'VDR',
#  'LOC101905514',
#  'LOC101905666',
#  'HDAC7',
#  'SLC48A1',
#  'LOC101905586',
#  'RAPGEF3',
#  'LOC112446799',
#  'ENDOU',
#  'RPAP3',
#  'LOC112446682',
#  'LOC101902438',
#  'LOC112446683',
#  'LOC112446684',
#  'LOC112446685',
#  'LOC107132477',
#  'PCED1B',
#  'LOC100847695',
#  'AMIGO2',
#  'LOC112446608',
#  'SLC38A4',
#  'LOC112446686',
#  'LOC107132478',
#  'LOC112446800',
#  'SLC38A2',
#  'SLC38A1',
#  'LOC112446688',
#  'SCAF11',
#  'ARID2',
#  'ANO6',
#  'LOC784769',
#  'DBX2',
#  'NELL2',
#  'LOC101906916',
#  'TMEM117',
#  'TWF1',
#  'IRAK4',
#  'PUS7L',
#  'ADAMTS20',
#  'LOC534627',
#  'LOC112446902',
#  'LOC786089',
#  'TRNAS-GGA',
#  'LOC112446856',
#  'LOC112446801',
#  'MUC19',
#  'LOC534391',
#  'LRRK2',
#  'SLC2A13',
#  'C5H12orf40',
#  'ABCD2',
#  'LOC785955',
#  'LOC100847470',
#  'KIF21A',
#  'MIR2428',
#  'LOC112446895',
#  'LOC617654',
#  'CPNE8',
#  'PTPRR',
#  'LOC112446905',
#  'LOC112446692',
#  'PTPRB',
#  'MIR2284Z-5',
#  'KCNMB4',
#  'LOC112446691',
#  'CNOT2',
#  'LOC107131684',
#  'LOC104972423',
#  'MYRFL',
#  'RAB3IP',
#  'LOC107132482',
#  'BEST3',
#  'LRRC10',
#  'CCT2',
#  'FRS2',
#  'MIR2427',
#  'LOC100138933',
#  'YEATS4',
#  'LYZ1',
#  'LOC112446887',
#  'LOC112446915',
#  'LOC785803',
#  'LOC781146',
#  'LOC112446693',
#  'LOC112446695',
#  'LOC112446889',
#  'LOC617219',
#  'LOC112446694',
#  'LOC112446890',
#  'LYSB',
#  'LYZ2',
#  'LYZ3',
#  'LOC787241',
#  'LOC112446907',
#  'LYZ',
#  'CPSF6',
#  'LOC107132485',
#  'LOC112446864',
#  'LOC104969823',
#  'CPM',
#  'LOC112446696',
#  'MDM2',
#  'SRGAP1',
#  'RXYLT1',
#  'AVPR1A',
#  'LOC100140195',
#  'PPM1H',
#  'LOC112446702',
#  'LOC104972443',
#  'LOC784406',
#  'MIRLET7I',
#  'MON2',
#  'USP15',
#  'FAM19A2',
#  'LOC101903699',
#  'LOC101904412',
#  'ATP23',
#  'LOC112446704',
#  'CTDSP2',
#  'MIR26A-2',
#  'AVIL',
#  'TSFM',
#  'EEF1AKMT3',
#  'METTL1',
#  'CYP27B1',
#  'MARCH9',
#  'CDK4',
#  'TSPAN31',
#  'AGAP2',
#  'LOC112446705',
#  'OS9',
#  'LOC112446803',
#  'B4GALNT1',
#  'SLC26A10',
#  'ARHGEF25',
#  'DTX3',
#  'PIP4K2C',
#  'KIF5A',
#  'DCTN2',
#  'MBD6',
#  'DDIT3',
#  'MARS',
#  'MIR2430',
#  'ARHGAP9',
#  'GLI1',
#  'INHBE',
#  'INHBC',
#  'R3HDM2',
#  'STAC3',
#  'LOC112446707',
#  'LOC112446706',
#  'NDUFA4L2',
#  'SHMT2',
#  'NXPH4',
#  'LRP1',
#  'LOC112446855',
#  'MIR2431',
#  'STAT6',
#  'LOC101902542',
#  'LOC100336976',
#  'NEMP1',
#  'MYO1A',
#  'TAC3',
#  'ZBTB39',
#  'GPR182',
#  'LOC100295935',
#  'LOC522844',
#  'LOC112446612',
#  'LOC100139075',
#  'LOC112446804',
#  'RDH16',
#  'SDR9C7',
#  'LOC100294910',
#  'LOC100138638',
#  'LOC112446873',
#  'LOC112446872',
#  'HSD17B6',
#  'PRIM1',
#  'NACA',
#  'LOC784846',
#  'PTGES3',
#  'ATP5F1B',
#  'LOC112446861',
#  'LOC112446708',
#  'MIR677',
#  'BAZ2A',
#  'RBMS2',
#  'GLS2',
#  'SPRYD4',
#  'MIP',
#  'TIMELESS',
#  'ApoN',
#  'STAT2',
#  'IL23A',
#  'MIR2432',
#  'LOC107132490',
#  'CNPY2',
#  'CS',
#  'LOC112446709',
#  'COQ10A',
#  'ANKRD52',
#  'MIR2433',
#  'NABP2',
#  'RNF41',
#  'LOC112446710',
#  'TRNAS-CGA',
#  'MYL6',
#  'MYL6B',
#  'LOC112446711',
#  'ESYT1',
#  'LOC101903253',
#  'ZC3H10',
#  'PA2G4',
#  'ERBB3',
#  'RPS26',
#  'IKZF4',
#  'SUOX',
#  'RAB5B',
#  'CDK2',
#  'PMEL',
#  'DGKA',
#  'PYM1',
#  'LOC107132498',
#  'MMP19',
#  'LOC507581',
#  'DNAJC14',
#  'ORMDL2',
#  'SARNP',
#  'GDF11',
#  'LOC101903534',
#  'CD63',
#  'RDH5',
#  'BLOC1S1',
#  'ITGA7',
#  'METTL7B',
#  'LOC520938',
#  'LOC112446881',
#  'OR10P1',
#  'OR6C4',
#  'LOC112446805',
#  'LOC781363',
#  'OR2AP1',
#  'LOC101903758',
#  'LOC100847112',
#  'LOC615284',
#  'LOC618816',
#  'LOC506139',
#  'LOC526713',
#  'LOC782840',
#  'LOC510046',
#  'LOC112446806',
#  'LOC529303',
#  'LOC782659',
#  'LOC782624',
#  'LOC782591',
#  'LOC782550',
#  'LOC112446906',
#  'LOC100140445',
#  'GAS2L3',
#  'LOC112446714',
#  'LOC112446715',
#  'LOC112446713',
#  'ANO4',
#  'MIR2434',
#  'LOC101905784',
#  'SLC5A8',
#  'LOC101908204',
#  'UTP20',
#  'ARL1',
#  'LOC101902002',
#  'SPIC',
#  'MYBPC1',
#  'CHPT1',
#  'LOC112446716',
#  'SYCP3',
#  'GNPTAB',
#  'LOC101902154',
#  'DRAM1',
#  'LOC782673',
#  'LOC104972477',
#  'WASHC3',
#  'NUP37',
#  'LOC101904077',
#  'PARPBP',
#  'PMCH',
#  'LOC112446820',
#  'LOC783823',
#  'LOC112446717',
#  'IGF1',
#  'LOC112446897',
#  'LOC101902701',
#  'LOC112446839',
#  'PAH',
#  'ASCL1',
#  'LOC101906016',
#  'LOC112446884',
#  'LOC112446615',
#  'C5H12orf42',
#  'STAB2',
#  'NT5DC3',
#  'LOC505479',
#  'HSP90B1',
#  'C5H12orf73',
#  'TDG',
#  'GLT8D2',
#  'HCFC2',
#  'NFYB',
#  'MIR2435',
#  'TRNAA-UGC',
#  'LOC101906262',
#  'EID3',
#  'LOC112446721',
#  'CHST11',
#  'LOC112446720',
#  'SLC41A2',
#  'C5H12orf45',
#  'ALDH1L2',
#  'LOC786352',
#  'LOC515697',
#  'LOC518495',
#  'LOC788334',
#  'LOC524576',
#  'LOC112446725',
#  'APOL3',
#  'LOC112446726',
#  'LOC619179',
#  'LOC101906044',
#  'MYH9',
#  'LOC112446616',
#  'LOC112446838',
#  'TXN2',
#  'FOXRED2',
#  'EIF3D',
#  'CACNG2',
#  'IFT27',
#  'LOC101906435',
#  'PVALB',
#  'NCF4',
#  'CSF2RB',
#  'LOC788541',
#  'TEX33',
#  'TST',
#  'MPST',
#  'KCTD17',
#  'TMPRSS6',
#  'IL2RB',
#  'LOC510185',
#  'C1QTNF6',
#  'LOC112446727',
#  'SSTR3',
#  'RAC2',
#  'MIR1835',
#  'CYTH4',
#  'ELFN2',
#  'MFNG',
#  'CARD10',
#  'LOC112446845',
#  'LOC112446901',
#  'USP18',
#  'ALG10',
#  'KLHL42',
#  'MANSC4',
#  'MRPS35',
#  'LOC781532',
#  'REP15',
#  'PPFIBP1',
#  'C5H12orf71',
#  'LOC781688',
#  'SMCO2',
#  'LOC112446918',
#  'ARNTL2',
#  'STK38L',
#  'MED21',
#  'TM7SF3',
#  'FGFR1OP2',
#  'INTS13',
#  'LOC112446618',
#  'LOC112446733',
#  'ITPR2',
#  'SSPN',
#  'LOC107132515',
#  'BHLHE41',
#  'MIR2436',
#  'LOC112446734',
#  'LMNTD1',
#  'KRAS',
#  'LOC104972526',
#  'ETFRF1',
#  'CASC1',
#  'LRMP',
#  'LOC112446824',
#  'BCAT1',
#  'LOC100295631',
#  'SOX5',
#  'ETNK1',
#  'C2CD5',
#  'ST8SIA1',
#  'LOC112446735',
#  'LOC112446736',
#  'CMAS',
#  'ABCC9',
#  'KCNJ8',
#  'GYS2',
#  'SPX',
#  'GOLT1B',
#  'RECQL',
#  'PYROXD1',
#  'SLCO1A2',
#  'IAPP',
#  'SLCO1B3',
#  'LOC101905711',
#  'LOC112446909',
#  'SLCO1C1',
#  'PDE3A',
#  'LMO3',
#  'LOC618358',
#  'MGST1',
#  'SLC15A5',
#  'DERA',
#  'LOC338087',
#  'STRAP',
#  'LOC112446862',
#  'EPS8',
#  'PTPRO',
#  'RERG',
#  'LOC112446622',
#  'PDE6H',
#  'ARHGDIB',
#  'ERP27',
#  'MGP',
#  'ART4',
#  'SMCO3',
#  'C5H12orf60',
#  'WBP11',
#  'H2AFJ',
#  'LOC530773',
#  'GUCY2C',
#  'PLBD1',
#  'LOC504273',
#  'LOC100139276',
#  'ATF7IP',
#  'LOC112446913',
#  'LOC100139060',
#  'GRIN2B',
#  'TAS2R8',
#  'LOC104972542',
#  'YBX3',
#  'MAGOHB',
#  'KLRA1',
#  'LOC101902742',
#  'LOC101902704',
#  'LOC513869',
#  'LOC788694',
#  'LOC100140174',
#  'LOC112446743',
#  'KLRC1',
#  'LOC101904370',
#  'LOC104970137',
#  'LOC100847738',
#  'LOC101905165',
#  'LOC100336869',
#  'LOC101904903',
#  'KLRJ1',
#  'LOC100296778',
#  'LOC101905403',
#  'NKG2A',
#  'NKG2C',
#  'LOC100847813',
#  'KLRK1',
#  'KLRD1',
#  'LOC618565',
#  'LOC100848575',
#  'GABARAPL1',
#  'TMEM52B',
#  'OLR1',
#  'CLEC7A',
#  'CLEC1A',
#  'CLEC9A',
#  'CLEC1B',
#  'CLEC12B',
#  'CLEC12A',
#  'LOC785168',
#  'LOC784329',
#  'LOC100847268',
#  'KLRF2',
#  'CLEC2B',
#  'LOC617565',
#  'LOC509972',
#  'LOC784451',
#  'LOC101905748',
#  'LOC104972552',
#  'KLRF1',
#  'LOC101905801',
#  'CD69',
#  'LOC100294723',
#  'LOC107132519',
#  'LOC112446891',
#  'LOC100297676',
#  'LOC112446744',
#  'LOC104972545',
#  'LOC100297770',
#  'LOC100138381',
#  'OVOS2',
#  'LOC112446837',
#  'LOC506828',
#  'WC1.3',
#  'WC1',
#  'WC1-8',
#  'CD163L1',
#  'PEX5',
#  'CLSTN3',
#  'RBP5',
#  'C1RL',
#  'C1R',
#  'C1S',
#  'LPCAT3',
#  'EMG1',
#  'PHB2',
#  'MIR141',
#  'MIR200C',
#  'PTPN6',
#  'C5H12orf57',
#  'ATN1',
#  'ENO2',
#  'LRRC23',
#  'SPSB2',
#  'TPI1',
#  'USP5',
#  'CDCA3',
#  'GNB3',
#  'GPR162',
#  'CD4',
#  'LAG3',
#  'PTMS',
#  'MLF2',
#  'COPS7A',
#  'PIANP',
#  'ZNF384',
#  'ING4',
#  'ACRBP',
#  'LPAR5',
#  'CHD4',
#  'NOP2',
#  'IFFO1',
#  'GAPDH',
#  'NCAPD2',
#  'MIR2424',
#  'MRPL51',
#  'VAMP1',
#  'TAPBPL',
#  'CD27',
#  'LTBR',
#  'SCNN1A',
#  'TNFRSF1A',
#  'PLEKHG6',
#  'CD9',
#  'VWF',
#  'LOC112446761',
#  'ANO2',
#  'LOC100297751',
#  'NTF3',
#  'LOC104972566',
#  'LOC112446625',
#  'LOC112446626',
#  'KCNA5',
#  'KCNA1',
#  'KCNA6',
#  'GALNT8',
#  'NDUFA9',
#  'DYRK4',
#  'RAD51AP1',
#  'LOC100336013',
#  'FGF6',
#  'FGF23',
#  'LOC112446763',
#  'TIGAR',
#  'CCND2',
#  'LOC104972567',
#  'LOC107132523',
#  'LOC112446627',
#  'PARP11',
#  'CRACR2A',
#  'PRMT8',
#  'LOC100847686',
#  'LOC112446764',
#  'TSPAN11',
#  'TSPAN9',
#  'LOC101902968',
#  'LOC104972568',
#  'TEAD4',
#  'TULP3',
#  'RHNO1',
#  'FOXM1',
#  'LOC104972569',
#  'TEX52',
#  'NRIP2',
#  'ITFG2',
#  'FKBP4',
#  'DDX11',
#  'WASHC1',
#  'IQSEC3',
#  'LOC104972570',
#  'SLC6A12',
#  'LOC112446765',
#  'SLC6A13',
#  'KDM5A',
#  'LOC781777',
#  'CCDC77',
#  'B4GALNT3',
#  'LOC112446858',
#  'NINJ2',
#  'LOC104972574',
#  'LOC112446767',
#  'LOC112446903',
#  'MIR2437',
#  'LOC112446768',
#  'WNK1',
#  'RAD52',
#  'ERC1',
#  'LOC112446770',
#  'LOC112446769',
#  'WNT5B',
#  'FBXL14',
#  'ADIPOR2',
#  'LOC104972578',
#  'CACNA2D4',
#  'LRTM2',
#  'DCP1B',
#  'CACNA1C',
#  'TRNAY-GUA',
#  'LOC104970340',
#  'TMEM121B',
#  'HDHD5',
#  'ADA2',
#  'LOC104970683',
#  'CECR2',
#  'LOC112446914',
#  'BCL2L13',
#  'LOC104972584',
#  'BID',
#  'LOC104972586',
#  'SH3BP1',
#  'PDXP',
#  'LOC100847870',
#  'LGALS1',
#  'NOL12',
#  'MIR2438',
#  'TRIOBP',
#  'H1F0',
#  'GCAT',
#  'GALR3',
#  'ANKRD54',
#  'MIR658',
#  'EIF3L',
#  'MICALL1',
#  'C5H22orf23',
#  'POLR2F',
#  'SOX10',
#  'LOC101905166',
#  'PICK1',
#  'SLC16A8',
#  'BAIAP2L2',
#  'PLA2G6',
#  'MAFF',
#  'TMEM184B',
#  'CSNK1E',
#  'KCNJ4',
#  'KDELR3',
#  'DDX17',
#  'DMC1',
#  'FAM227A',
#  'LOC112446908',
#  'CBY1',
#  'TOMM22',
#  'JOSD1',
#  'GTPBP1',
#  'SUN2',
#  'DNAL4',
#  'NPTXR',
#  'CBX6',
#  'ADSL',
#  'SGSM3',
#  'MKL1',
#  'MIR2439',
#  'MCHR1',
#  'SLC25A17',
#  'ST13',
#  'XPNPEP3',
#  'DNAJB7',
#  'RBX1',
#  'MIR1281',
#  'EP300',
#  'L3MBTL2',
#  'MIR2441',
#  'CHADL',
#  'RANGAP1',
#  'ZC3H7B',
#  'TEF',
#  'TOB2',
#  'PHF5A',
#  'ACO2',
#  'POLR3H',
#  'TRNAM-CAU',
#  'CSDC2',
#  'PMM1',
#  'DESI1',
#  'XRCC6',
#  'SNU13',
#  'C5H22orf46',
#  'MEI1',
#  'CCDC134',
#  'SREBF2',
#  'MIR33A',
#  'SHISA8',
#  'TNFRSF13C',
#  'CENPM',
#  'SEPT3',
#  'WBP2NL',
#  'NAGA',
#  'PHETA2',
#  'SMDT1',
#  'NDUFA6',
#  'MGC127055',
#  'CYP2D14',
#  'MIR2442',
#  'TCF20',
#  'NFAM1',
#  'SERHL2',
#  'RRP7A',
#  'POLDIP3',
#  'CYB5R3',
#  'A4GALT',
#  'TACR3',
#  'CENPE',
#  'BDH2',
#  'SLC9B2',
#  'NHEDC1',
#  'CISD2',
#  'UBE2D3',
#  'MANBA',
#  'NFKB1',
#  'SLC39A8',
#  'GPRIN3',
#  'TIGD2',
#  'FAM13A',
#  'LOC104972724',
#  'HERC3',
#  'LOC100847719',
#  'NAP1L5',
#  'PIGY',
#  'PYURF',
#  'HERC5',
#  'HERC6',
#  'PPM1K',
#  'ABCG2',
#  'LOC112447205']

# %%
#para crear los links correspondientess de busqueda tenemos que hacer una modificaciones
lista=[]
for genes in lista_genes:
#len(Datos.iloc[818:1637])
    lista.append(genes.replace(" ", "+"))
#print(lista)

lista1=[]
for genes in lista:
    lista1.append(genes.replace("(","%28"))
#print(lista1)

query=[]
for genes in lista1:
    query.append(genes.replace(")","%29"))
print(query)
len(query)
# Out:
# ['MIR2426', 'PRKAG1', 'DDN', 'WNT10B', 'LOC112446681', 'ARF3', 'FKBP11', 'CCDC65', 'RND1', 'DDX23', 'CACNB3', 'ADCY6', 'TEX49', 'LOC107132475', 'CCNT1', 'KANSL2', 'LOC112446865', 'LOC112446866', 'MIR1291', 'LOC783895', 'LALBA', 'LOC104972406', 'LOC617415', 'LOC526630', 'LOC614370', 'LOC515887', 'OR8S27+LOC506992', 'OR8S25+LOC781446', 'OR8S10+LOC509508', 'LOC781517', 'OR8S15+LOC507383', 'LOC781595', 'OR8S1', 'OR8S24+LOC504567', 'LOC781756', 'LOC781840', 'LOC101907855', 'C5H12orf54', 'OR8S2+LOC509817', 'OR8S26+LOC781968', 'OR8S3+LOC617388', 'LOC617380', 'LOC518129', 'LOC100300010', 'OR5BJ2+LOC523258', 'LOC100848234', 'ZNF641', 'H1-7++LOC784038', 'H1FNT', 'LOC513452', 'LOC619137', 'LOC101902265', 'LOC101905376', 'LOC104972407', 'OR10AD1', 'CCDC184', 'LOC100139168', 'ASB8', 'PFKM', 'SENP1', 'COL2A1', 'TMEM106C', 'VDR', 'LOC101905514', 'LOC101905666', 'HDAC7', 'SLC48A1', 'LOC101905586', 'RAPGEF3', 'LOC112446799', 'ENDOU', 'RPAP3', 'LOC112446682', 'LOC101902438', 'LOC112446683', 'LOC112446684', 'LOC112446685', 'LOC107132477', 'PCED1B', 'LOC100847695', 'AMIGO2', 'LOC112446608', 'SLC38A4', 'LOC112446686', 'LOC107132478', 'LOC112446800', 'SLC38A2', 'SLC38A1', 'LOC112446688', 'SCAF11', 'ARID2', 'ANO6', 'LOC784769', 'DBX2', 'NELL2', 'LOC101906916', 'TMEM117', 'TWF1', 'IRAK4', 'PUS7L', 'ADAMTS20', 'LOC534627', 'LOC112446902', 'LOC786089', 'TRNAS-GGA', 'LOC112446856', 'LOC112446801', 'MUC19', 'LOC534391', 'LRRK2', 'SLC2A13', 'C5H12orf40', 'ABCD2', 'LOC785955', 'LOC100847470', 'KIF21A', 'MIR2428', 'LOC112446895', 'LOC617654', 'CPNE8', 'PTPRR', 'LOC112446905', 'LOC112446692', 'PTPRB', 'MIR2284Z-5', 'KCNMB4', 'LOC112446691', 'CNOT2', 'LOC107131684', 'LOC104972423', 'MYRFL', 'RAB3IP', 'LOC107132482', 'BEST3', 'LRRC10', 'CCT2', 'FRS2', 'MIR2427', 'LOC100138933', 'YEATS4', 'LYZ1', 'LOC112446887', 'LOC112446915', 'LOC785803', 'LOC781146', 'LOC112446693', 'LOC112446695', 'LOC112446889', 'LOC617219', 'LOC112446694', 'LOC112446890', 'LYSB', 'LYZ2', 'LYZ3', 'LOC787241', 'LOC112446907', 'LYZ', 'CPSF6', 'LOC107132485', 'LOC112446864', 'LOC104969823', 'CPM', 'LOC112446696', 'MDM2', 'SRGAP1', 'RXYLT1', 'AVPR1A', 'LOC100140195', 'PPM1H', 'LOC112446702', 'LOC104972443', 'LOC784406', 'MIRLET7I', 'MON2', 'USP15', 'FAM19A2', 'LOC101903699', 'LOC101904412', 'ATP23', 'LOC112446704', 'CTDSP2', 'MIR26A-2', 'AVIL', 'TSFM', 'EEF1AKMT3', 'METTL1', 'CYP27B1', 'MARCH9', 'CDK4', 'TSPAN31', 'AGAP2', 'LOC112446705', 'OS9', 'LOC112446803', 'B4GALNT1', 'SLC26A10', 'ARHGEF25', 'DTX3', 'PIP4K2C', 'KIF5A', 'DCTN2', 'MBD6', 'DDIT3', 'MARS', 'MIR2430', 'ARHGAP9', 'GLI1', 'INHBE', 'INHBC', 'R3HDM2', 'STAC3', 'LOC112446707', 'LOC112446706', 'NDUFA4L2', 'SHMT2', 'NXPH4', 'LRP1', 'LOC112446855', 'MIR2431', 'STAT6', 'LOC101902542', 'LOC100336976', 'NEMP1', 'MYO1A', 'TAC3', 'ZBTB39', 'GPR182', 'LOC100295935', 'LOC522844', 'LOC112446612', 'LOC100139075', 'LOC112446804', 'RDH16', 'SDR9C7', 'LOC100294910', 'LOC100138638', 'LOC112446873', 'LOC112446872', 'HSD17B6', 'PRIM1', 'NACA', 'LOC784846', 'PTGES3', 'ATP5F1B', 'LOC112446861', 'LOC112446708', 'MIR677', 'BAZ2A', 'RBMS2', 'GLS2', 'SPRYD4', 'MIP', 'TIMELESS', 'ApoN', 'STAT2', 'IL23A', 'MIR2432', 'LOC107132490', 'CNPY2', 'CS', 'LOC112446709', 'COQ10A', 'ANKRD52', 'MIR2433', 'NABP2', 'RNF41', 'LOC112446710', 'TRNAS-CGA', 'MYL6', 'MYL6B', 'LOC112446711', 'ESYT1', 'LOC101903253', 'ZC3H10', 'PA2G4', 'ERBB3', 'RPS26', 'IKZF4', 'SUOX', 'RAB5B', 'CDK2', 'PMEL', 'DGKA', 'PYM1', 'LOC107132498', 'MMP19', 'LOC507581', 'DNAJC14', 'ORMDL2', 'SARNP', 'GDF11', 'LOC101903534', 'CD63', 'RDH5', 'BLOC1S1', 'ITGA7', 'METTL7B', 'LOC520938', 'LOC112446881', 'OR10P1', 'OR6C4', 'LOC112446805', 'LOC781363', 'OR2AP1', 'LOC101903758', 'LOC100847112', 'LOC615284', 'LOC618816', 'LOC506139', 'LOC526713', 'LOC782840', 'LOC510046', 'LOC112446806', 'LOC529303', 'LOC782659', 'LOC782624', 'LOC782591', 'LOC782550', 'LOC112446906', 'LOC100140445', 'GAS2L3', 'LOC112446714', 'LOC112446715', 'LOC112446713', 'ANO4', 'MIR2434', 'LOC101905784', 'SLC5A8', 'LOC101908204', 'UTP20',  ...
# 818

# %%
LISTA_GENES= query[0:200]
print(LISTA_GENES)
len(LISTA_GENES)
# Out:
# ['MIR2426', 'PRKAG1', 'DDN', 'WNT10B', 'LOC112446681', 'ARF3', 'FKBP11', 'CCDC65', 'RND1', 'DDX23', 'CACNB3', 'ADCY6', 'TEX49', 'LOC107132475', 'CCNT1', 'KANSL2', 'LOC112446865', 'LOC112446866', 'MIR1291', 'LOC783895', 'LALBA', 'LOC104972406', 'LOC617415', 'LOC526630', 'LOC614370', 'LOC515887', 'OR8S27+LOC506992', 'OR8S25+LOC781446', 'OR8S10+LOC509508', 'LOC781517', 'OR8S15+LOC507383', 'LOC781595', 'OR8S1', 'OR8S24+LOC504567', 'LOC781756', 'LOC781840', 'LOC101907855', 'C5H12orf54', 'OR8S2+LOC509817', 'OR8S26+LOC781968', 'OR8S3+LOC617388', 'LOC617380', 'LOC518129', 'LOC100300010', 'OR5BJ2+LOC523258', 'LOC100848234', 'ZNF641', 'H1-7++LOC784038', 'H1FNT', 'LOC513452', 'LOC619137', 'LOC101902265', 'LOC101905376', 'LOC104972407', 'OR10AD1', 'CCDC184', 'LOC100139168', 'ASB8', 'PFKM', 'SENP1', 'COL2A1', 'TMEM106C', 'VDR', 'LOC101905514', 'LOC101905666', 'HDAC7', 'SLC48A1', 'LOC101905586', 'RAPGEF3', 'LOC112446799', 'ENDOU', 'RPAP3', 'LOC112446682', 'LOC101902438', 'LOC112446683', 'LOC112446684', 'LOC112446685', 'LOC107132477', 'PCED1B', 'LOC100847695', 'AMIGO2', 'LOC112446608', 'SLC38A4', 'LOC112446686', 'LOC107132478', 'LOC112446800', 'SLC38A2', 'SLC38A1', 'LOC112446688', 'SCAF11', 'ARID2', 'ANO6', 'LOC784769', 'DBX2', 'NELL2', 'LOC101906916', 'TMEM117', 'TWF1', 'IRAK4', 'PUS7L', 'ADAMTS20', 'LOC534627', 'LOC112446902', 'LOC786089', 'TRNAS-GGA', 'LOC112446856', 'LOC112446801', 'MUC19', 'LOC534391', 'LRRK2', 'SLC2A13', 'C5H12orf40', 'ABCD2', 'LOC785955', 'LOC100847470', 'KIF21A', 'MIR2428', 'LOC112446895', 'LOC617654', 'CPNE8', 'PTPRR', 'LOC112446905', 'LOC112446692', 'PTPRB', 'MIR2284Z-5', 'KCNMB4', 'LOC112446691', 'CNOT2', 'LOC107131684', 'LOC104972423', 'MYRFL', 'RAB3IP', 'LOC107132482', 'BEST3', 'LRRC10', 'CCT2', 'FRS2', 'MIR2427', 'LOC100138933', 'YEATS4', 'LYZ1', 'LOC112446887', 'LOC112446915', 'LOC785803', 'LOC781146', 'LOC112446693', 'LOC112446695', 'LOC112446889', 'LOC617219', 'LOC112446694', 'LOC112446890', 'LYSB', 'LYZ2', 'LYZ3', 'LOC787241', 'LOC112446907', 'LYZ', 'CPSF6', 'LOC107132485', 'LOC112446864', 'LOC104969823', 'CPM', 'LOC112446696', 'MDM2', 'SRGAP1', 'RXYLT1', 'AVPR1A', 'LOC100140195', 'PPM1H', 'LOC112446702', 'LOC104972443', 'LOC784406', 'MIRLET7I', 'MON2', 'USP15', 'FAM19A2', 'LOC101903699', 'LOC101904412', 'ATP23', 'LOC112446704', 'CTDSP2', 'MIR26A-2', 'AVIL', 'TSFM', 'EEF1AKMT3', 'METTL1', 'CYP27B1', 'MARCH9', 'CDK4', 'TSPAN31', 'AGAP2', 'LOC112446705', 'OS9', 'LOC112446803', 'B4GALNT1', 'SLC26A10', 'ARHGEF25', 'DTX3', 'PIP4K2C', 'KIF5A']
# 200

# %%
links=[]

for i in query:
    links.append("https://www.uniprot.org/uniprot/?query="+ str(i) + "+Bos+taurus&sort=score")
#print(links)

# %% [markdown]
# ### PRIMERA EXTRACCIÓN DE LOS 200 PRIMEROS LINKS

# %%
#######################
# COLUMNA2 ENTRY 
#######################


import urllib.request, urllib.parse, urllib.error #(solicitud,analizar,error)
import re
import ssl  
ctx = ssl.create_default_context()                    #crear un contexto predeterminado
ctx.check_hostname = False                            #comprobar el nombre de host
ctx.verify_mode = ssl.CERT_NONE                       #modo de verificación

LISTA_ENTRY = []

for codigo in links[0:200]:
    url = codigo
    html = urllib.request.urlopen(url, context=ctx).read()  
    link = re.findall(b'<a href=".uniprot.([a-zA-Z].*?)"', html) 
    if len(link)==0:
        LISTA_ENTRY.append("Na")
    else:
        objeto=link[0].decode()
        LISTA_ENTRY = LISTA_ENTRY +[objeto] 
print(LISTA_ENTRY)   
len(LISTA_ENTRY)
# Out:
# ['Na', 'P58108', 'Q3B7N2', 'F1MK64', 'Na', 'O02810', 'Q2YDL5', 'Q2TA16', 'Q2HJ68', 'Q3B8S0', 'Q9MZL3', 'A7E3S4', 'A0A4W2HZT3', 'Na', 'Q6T8E9', 'Q2NL14', 'Na', 'Na', 'Na', 'Na', 'P00711', 'Na', 'Na', 'Na', 'Na', 'E1BEY3', 'F1MLF2', 'A0A3Q1LVL1', 'A0A3Q1MA08', 'Na', 'A0A3Q1MA20', 'Na', 'F1MQF3', 'F1N475', 'Na', 'Na', 'Na', 'Q3SZX7', 'A0A3Q1MKL2', 'A0A3Q1MY61', 'G5E5H8', 'Na', 'Na', 'Na', 'F1MRF0', 'Na', 'E1BNN9', 'A0A3Q1M3C8', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'F1MDQ7', 'Q0VC19', 'Na', 'Q08E43', 'Q0IIG5', 'P25500', 'P02459', 'Q3T144', 'Q28037', 'Na', 'Na', 'Q2KIA0', 'E1BKJ0', 'Na', 'F1MSG6', 'Na', 'A6QLQ8', 'Q0VCI6', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'A6QL70', 'Na', 'A0A4W2I8N4', 'Na', 'F1MM24', 'Na', 'Na', 'Na', 'A2VE31', 'A7MB74', 'Na', 'Q1RMR2', 'A7Z019', 'A0A3Q1M2M7', 'Na', 'Q17QR5', 'A6QR11', 'Na', 'A6QQU3', 'Q56JV6', 'Q1RMT8', 'E1BGT6', 'E1B900', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'F2FB39', 'Na', 'E1BPU0', 'E1BML6', 'Na', 'P10103', 'Na', 'Na', 'F1MJ53', 'Na', 'Na', 'Na', 'A5D784', 'A5PKF8', 'Na', 'Na', 'Q06807', 'Na', 'Q28204', 'Na', 'A0A4W2DD20', 'Na', 'Na', 'F1N4M2', 'A4FV54', 'Na', 'E1BF90', 'Q24K06', 'Q3ZBH0', 'P19534', 'Na', 'Na', 'Q2TBU9', 'P04421', 'Na', 'Na', 'G1K230', 'A0A3Q1M4Y5', 'F1MEC3', 'Na', 'Na', 'G5E502', 'Na', 'Na', 'Na', 'Q06283', 'Q06284', 'Na', 'Na', 'P00711', 'Q0P5D2', 'A0A3Q1MQV9', 'Na', 'Na', 'P00189', 'Na', 'A0A4W2CSU9', 'A0A3Q1LMM5', 'F1MKC5', 'P01175', 'Na', 'F1MFZ6', 'Na', 'Na', 'Na', 'Na', 'Q1RMH8', 'Q2HJE4', 'Na', 'Na', 'Na', 'F1MY08', 'Na', 'Q2KJ43', 'Na', 'P61157', 'P49410', 'A4FV98', 'Q2YDF1', 'E1BN35', 'Q95132', 'Q32KY4', 'Q32KP1', 'A0JNB0', 'Na', 'Q3MHX6', 'Na', 'Q58DI2', 'F1MWU6', 'F1MWU7', 'E1BH71', 'Q0P5F7', 'A0A3Q1MWH8']
# 200

# %%
############################
# COLUMNA3 ENTRY NAME 
############################

LISTA_ENTRYNAME = []

for codigo in links[0:200]:
    url = codigo
    html = urllib.request.urlopen(url, context=ctx).read()  
    link = re.findall(b'<td>([A-Z].*?)<.td>', html) 
    if len(link)==0:
        LISTA_ENTRYNAME.append('Na')
    else:
        objeto=link[0].decode()
        LISTA_ENTRYNAME=LISTA_ENTRYNAME +[objeto] 
print(LISTA_ENTRYNAME)    
len(LISTA_ENTRYNAME)
# Out:
# ['Na', 'AAKG1_BOVIN', 'ACTN1_BOVIN', 'F1MK64_BOVIN', 'Na', 'PI4KB_BOVIN', 'FKB11_BOVIN', 'DRC2_BOVIN', 'RND1_BOVIN', 'NH2L1_BOVIN', 'CACB3_BOVIN', 'RAF1_BOVIN', 'A0A4W2HZT3_BOBOX', 'Na', 'CCNT1_BOVIN', 'KANL2_BOVIN', 'Na', 'Na', 'Na', 'Na', 'LALBA_BOVIN', 'Na', 'Na', 'Na', 'Na', 'E1BEY3_BOVIN', 'F1MLF2_BOVIN', 'A0A3Q1LVL1_BOVIN', 'A0A3Q1MA08_BOVIN', 'Na', 'A0A3Q1MA20_BOVIN', 'Na', 'F1MQF3_BOVIN', 'F1N475_BOVIN', 'Na', 'Na', 'Na', 'CL054_BOVIN', 'A0A3Q1MKL2_BOVIN', 'A0A3Q1MY61_BOVIN', 'G5E5H8_BOVIN', 'Na', 'Na', 'Na', 'F1MRF0_BOVIN', 'Na', 'E1BNN9_BOVIN', 'A0A3Q1M3C8_BOVIN', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'F1MDQ7_BOVIN', 'CC184_BOVIN', 'Na', 'ASB8_BOVIN', 'PFKAM_BOVIN', 'PAPOA_BOVIN', 'CO2A1_BOVIN', 'T106C_BOVIN', 'VDR_BOVIN', 'Na', 'Na', 'MEF2C_BOVIN', 'E1BKJ0_BOVIN', 'Na', 'RPGF2_BOVIN', 'Na', 'ENDOU_BOVIN', 'PIHD1_BOVIN', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'PED1B_BOVIN', 'Na', 'A0A4W2I8N4_BOBOX', 'Na', 'F1MM24_BOVIN', 'Na', 'Na', 'Na', 'S38A2_BOVIN', 'SGK1_BOVIN', 'Na', 'RU17_BOVIN', 'SMCA4_BOVIN', 'A0A3Q1M2M7_BOVIN', 'Na', 'DBX2_BOVIN', 'NELL2_BOVIN', 'Na', 'A6QQU3_BOVIN', 'TWF1_BOVIN', 'IRAK4_BOVIN', 'E1BGT6_BOVIN', 'E1B900_BOVIN', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'F2FB39_BOVIN', 'Na', 'E1BPU0_BOVIN', 'E1BML6_BOVIN', 'Na', 'HMGB1_BOVIN', 'Na', 'Na', 'F1MJ53_BOVIN', 'Na', 'Na', 'Na', 'A5D784_BOVIN', 'A5PKF8_BOVIN', 'Na', 'Na', 'TIE2_BOVIN', 'Na', 'KCMA1_BOVIN', 'Na', 'A0A4W2DD20_BOBOX', 'Na', 'Na', 'MRFL_BOVIN', 'RAB8A_BOVIN', 'Na', 'E1BF90_BOVIN', 'LRC10_BOVIN', 'TCPB_BOVIN', 'CADH2_BOVIN', 'Na', 'Na', 'RUVB2_BOVIN', 'LYSC_BOVIN', 'Na', 'Na', 'G1K230_BOVIN', 'A0A3Q1M4Y5_BOVIN', 'F1MEC3_BOVIN', 'Na', 'Na', 'G5E502_BOVIN', 'Na', 'Na', 'Na', 'LYSC2_BOVIN', 'LYSC3_BOVIN', 'Na', 'Na', 'LALBA_BOVIN', 'CPSF6_BOVIN', 'A0A3Q1MQV9_BOVIN', 'Na', 'Na', 'CP11A_BOVIN', 'Na', 'A0A4W2CSU9_BOBOX', 'A0A3Q1LMM5_BOVIN', 'F1MKC5_BOVIN', 'NEU1_BOVIN', 'Na', 'F1MFZ6_BOVIN', 'Na', 'Na', 'Na', 'Na', 'SNX3_BOVIN', 'UBP15_BOVIN', 'Na', 'Na', 'Na', 'F1MY08_BOVIN', 'Na', 'Q2KJ43_BOVIN', 'Na', 'ARP3_BOVIN', 'EFTU_BOVIN', 'EFMT3_BOVIN', 'TRMB_BOVIN', 'E1BN35_BOVIN', 'ICAM1_BOVIN', 'CDK4_BOVIN', 'TSN31_BOVIN', 'FYN_BOVIN', 'Na', 'OS9_BOVIN', 'Na', 'Q58DI2_BOVIN', 'F1MWU6_BOVIN', 'F1MWU7_BOVIN', 'E1BH71_BOVIN', 'PI42C_BOVIN', 'A0A3Q1MWH8_BOVIN']
# 200

# %%
###########################################
# COLUMNA4 PROTEIN  
###########################################

urls=[]

for i in LISTA_ENTRY:
    if i=="Na":
        urls.append(0)
    else:
        urls.append("https://www.uniprot.org/uniprot/"+str(i))
#print(urls)
'''
PROTEINA=[]

for i in urls:
    if i==0:
        PROTEINA.append("Na")
#print(PROTEINA)
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h1 property="name">([a-zA-Z0-9].*?)<', html) 
        for link in links:
            nuevo=link.decode()
            PROTEINA = PROTEINA+[nuevo]
            
print(PROTEINA)
len(PROTEINA)
'''
# Out:
# '\nPROTEINA=[]\n\nfor i in urls:\n    if i==0:\n        PROTEINA.append("Na")\n#print(PROTEINA)\n    else:        \n        url = i\n        html = urllib.request.urlopen(url, context=ctx).read()  \n        links = re.findall(b\'<h1 property="name">([a-zA-Z0-9].*?)<\', html) \n        for link in links:\n            nuevo=link.decode()\n            PROTEINA = PROTEINA+[nuevo]\n            \nprint(PROTEINA)\nlen(PROTEINA)\n'

# %%
########################################
# COLUMNA5 GENES 
########################################

GENES=[]

for i in urls:
    if i==0:
        GENES.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h2>([A-Z].*?)<', html) 
        #print(links)
        if len(re.findall(b'<h2>([A-Z].*?)<', html))==1:  # Algunos Entrys no tienen el nombre de Gene, por lo tanto links saldría vacío, con len =0
            for link in links:
                nuevo=link.decode()
                GENES=GENES+[nuevo]
        else:
        
            GENES=GENES+["N/A"]
print(GENES)
len(GENES)
# Out:
# ['Na', 'PRKAG1', 'ACTN1', 'WNT10B', 'Na', 'PI4KB', 'FKBP11', 'CCDC65', 'RND1', 'SNU13', 'CACNB3', 'RAF1', 'TEX49', 'Na', 'CCNT1', 'KANSL2', 'Na', 'Na', 'Na', 'Na', 'LALBA', 'Na', 'Na', 'Na', 'Na', 'OR8S8', 'OR8S27', 'OR8S25', 'OR8S10', 'Na', 'OR8S15', 'Na', 'OR8S1', 'OR8S24', 'Na', 'Na', 'Na', 'N/A', 'OR8S2', 'OR8S26', 'OR8S3', 'Na', 'Na', 'Na', 'OR5BJ2', 'Na', 'ZNF641', 'H1-7', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'OR10AD1', 'CCDC184', 'Na', 'ASB8', 'PFKM', 'PAPOLA', 'COL2A1', 'TMEM106C', 'VDR', 'Na', 'Na', 'MEF2C', 'SLC48A1', 'Na', 'RAPGEF2', 'Na', 'ENDOU', 'PIH1D1', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'PCED1B', 'Na', 'AMIGO2', 'Na', 'SLC38A4', 'Na', 'Na', 'Na', 'SLC38A2', 'SGK1', 'Na', 'SNRNP70', 'SMARCA4', 'ANO6', 'Na', 'DBX2', 'NELL2', 'Na', 'TMEM117', 'TWF1', 'IRAK4', 'PUS7L', 'ADAMTS20', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'MUC19', 'Na', 'LRRK2', 'SLC2A13', 'Na', 'HMGB1', 'Na', 'Na', 'KIF21A', 'Na', 'Na', 'Na', 'CPNE8', 'PTPRR', 'Na', 'Na', 'TEK', 'Na', 'KCNMA1', 'Na', 'CNOT2', 'Na', 'Na', 'MYRFL', 'RAB8A', 'Na', 'BEST3', 'LRRC10', 'CCT2', 'CDH2', 'Na', 'Na', 'RUVBL2', 'LYZ1', 'Na', 'Na', 'LOC785803', 'LOC781146', 'LOC112446693', 'Na', 'Na', 'LOC617219', 'Na', 'Na', 'Na', 'LYZ2', 'LYZ3', 'Na', 'Na', 'LALBA', 'CPSF6', 'LOC107132485', 'Na', 'Na', 'CYP11A1', 'Na', 'MDM2', 'SRGAP2', 'RXYLT1', 'OXT', 'Na', 'PPM1H', 'Na', 'Na', 'Na', 'Na', 'SNX3', 'USP15', 'Na', 'Na', 'Na', 'ATP23', 'Na', 'CTDSP2', 'Na', 'ACTR3', 'TUFM', 'EEF1AKMT3', 'METTL1', 'CYP27B1', 'ICAM1', 'CDK4', 'TSPAN31', 'FYN', 'Na', 'OS9', 'Na', 'B4GALNT1', 'SLC26A10', 'ARHGEF25', 'DTX3L', 'PIP4K2C', 'KIF5A']
# 200

# %%
################################
# COLUMNA6 ORGANISMO 
################################

ORGANISMO=[]

for i in urls[0:200]:
    if i==0:
        ORGANISMO.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<em>([A-Z].*?)</em>', html) 
        if  len(links)==2:     # si hay más de un objeto en links o si hay exactamente 2.
            ORGANISMO=ORGANISMO+ [links[1]]   #agrega  a la lista solo el segundo objeto de la lista
        else:
            for link in links:
                nuevo=link.decode()
                ORGANISMO=ORGANISMO+[nuevo]
print(ORGANISMO)
len(ORGANISMO)
# Out:
# ['Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', b'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)']
# 200

# %%
################################
# COLUMNA7 STATUS  
################################

STATUS=[]

for i in urls:
    if i==0:
        STATUS.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<span>([UR].*viewed)', html) 
        for link in links:
            nuevo=link.decode()
            STATUS=STATUS+[nuevo]
print(STATUS)
len(STATUS)
# Out:
# ['Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Na', 'Na', 'Reviewed', 'Na', 'Na', 'Na', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Na', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Unreviewed', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Unreviewed', 'Na', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Reviewed', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Unreviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Na', 'Na', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Na', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Na', 'Na', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Reviewed', 'Na', 'Reviewed', 'Na', 'Unreviewed', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Na', 'Reviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Na', 'Unreviewed', 'Na', 'Na', 'Na', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Na', 'Reviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Unreviewed']
# 200

# %%
################################
# COLUMNA8 GO - Biological process  
################################

GO_Biological_process = []

for i in urls:
    if i==0:
        GO_Biological_process.append("Na")
    else:
        uclient=urlopen(i)
        pagehtml=uclient.read()
        uclient.close()                                    
        pagesoup=soup(pagehtml, "html.parser")
        page=pagesoup.find("ul",{"class":"noNumbering biological_process"}) 
        
        if page==None:
            GO_Biological_process.append("Na")
        else:
            location=page.find_all("a",{"onclick":"window.ga('UniProt-Entry-View', 'click', 'Display-GO-Term');"})
            #print(location)
            cadena = ""
            for i in range(0,len(location)):
                if location[i].text=="":
                    cadena = cadena + "-"
                else:
                    #GO_Biological_process.append(location[i].text)
                    cadena = cadena + location[i].text + "."
                #print(type(location[i].text))

            GO_Biological_process.append(cadena)

print(GO_Biological_process)
len(GO_Biological_process)
# Out:
# ['Na', 'cellular response to glucose starvation.fatty acid biosynthetic process.protein phosphorylation.regulation of catalytic activity.regulation of protein serine/threonine kinase activity.', 'establishment of localization.regulation of ATPase activity.regulation of neurotransmitter secretion.sarcomere organization.skeletal muscle fiber development.', 'bone trabecula formation.canonical Wnt signaling pathway.cell cycle arrest.cell fate commitment.cellular response to cAMP.cellular response to parathyroid hormone stimulus.chondrocyte differentiation.fungiform papilla development.G2/M transition of mitotic cell cycle.hematopoietic stem cell proliferation.lipid metabolic process.myoblast differentiation involved in skeletal muscle regeneration.negative regulation of cold-induced thermogenesis.negative regulation of epithelial cell proliferation.negative regulation of fat cell differentiation.negative regulation of transcription by RNA polymerase II.neuron differentiation.positive regulation of apoptotic process.positive regulation of bone mineralization.positive regulation of canonical Wnt signaling pathway.positive regulation of cell population proliferation.positive regulation of DNA-binding transcription factor activity.positive regulation of epithelial cell differentiation.positive regulation of G2/M transition of mitotic cell cycle.positive regulation of osteoblast differentiation.positive regulation of RNA polymerase II transcription preinitiation complex assembly.positive regulation of timing of anagen.protein stabilization.regulation of proteasomal ubiquitin-dependent protein catabolic process.regulation of skeletal muscle tissue development.sensory perception of taste.skeletal muscle fiber development.smoothened signaling pathway.', 'Na', 'phosphatidylinositol-mediated signaling.phosphatidylinositol phosphorylation.', 'Na', 'axonemal dynein complex assembly.cilium-dependent cell motility.regulation of cilium movement.', 'actin filament organization.cell migration.cortical cytoskeleton organization.establishment or maintenance of cell polarity.negative regulation of cell adhesion.neuron remodeling.regulation of actin cytoskeleton organization.regulation of cell shape.small GTPase mediated signal transduction.', 'box C/D snoRNP assembly.maturation of LSU-rRNA.maturation of SSU-rRNA.mRNA splicing, via spliceosome.single fertilization.', 'calcium ion transmembrane transport via high voltage-gated calcium channel.chemical synaptic transmission.neuromuscular junction development.positive regulation of high voltage-gated calcium channel activity.regulation of voltage-gated calcium channel activity.', 'activation of adenylate cyclase activity.activation of MAPKK activity.cell differentiation.death-inducing signaling complex assembly.face development.insulin secretion involved in cellular response to glucose stimulus.intermediate filament cytoskeleton organization.intracellular signal transduction.negative regulation of cell population proliferation.negative regulation of extrinsic apoptotic signaling pathway via death domain receptors.negative regulation of protein-containing complex assembly.neurotrophin TRK receptor signaling pathway.positive regulation of peptidyl-serine phosphorylation.positive regulation of transcription by RNA polymerase II.response to muscle stretch.signal transduction.somatic stem cell population maintenance.thymus development.thyroid gland development.', 'Na', 'Na', 'cell cycle.cell division.negative regulation of mRNA polyadenylation.positive regulation of DNA-templated transcription, elongation.positive regulation of transcription by RNA polymerase II.protein phosphorylation.regulation of transcription by RNA polymerase II.transcription, DNA-templated.viral process.', 'histone H4-K16 acetylation.histone H4-K5 acetylation.histone H4-K8 acetylation.', 'Na', 'Na', 'Na', 'Na', 'lactose biosynthetic process.response to 11-deoxycorticosterone.response to dehydroepiandrosterone.response to estradiol.respo ...
# 200

# %%
import pandas as pd
##Guardando un archivo de formato data frame
#Creamos un diccionario data
data = {'Gen abrev': LISTA_GENES,
        'Entry': LISTA_ENTRY,
        'Entry name': LISTA_ENTRYNAME,
        'Protein' : PROTEINA,
        'Gene': GENES,
        'Organism' : ORGANISMO,
        'Status': STATUS,
        'GO-Biological process': GO_Biological_process}
# Luego creamos un dataframe y especificamos las columnas.
df = pd.DataFrame(data, columns = ['Gen abrev','Entry','Entry name','Protein','Gene','Organism','Status', 'GO-Biological process'])

df
# Out:
#         Gen abrev       Entry        Entry name  \
# 0         MIR2426          Na                Na
# 1          PRKAG1      P58108       AAKG1_BOVIN
# 2             DDN      Q3B7N2       ACTN1_BOVIN
# 3          WNT10B      F1MK64      F1MK64_BOVIN
# 4    LOC112446681          Na                Na
# ..            ...         ...               ...
# 195      SLC26A10      F1MWU6      F1MWU6_BOVIN
# 196      ARHGEF25      F1MWU7      F1MWU7_BOVIN
# 197          DTX3      E1BH71      E1BH71_BOVIN
# 198       PIP4K2C      Q0P5F7       PI42C_BOVIN
# 199         KIF5A  A0A3Q1MWH8  A0A3Q1MWH8_BOVIN
#
#                                                Protein      Gene  \
# 0                                                   Na        Na
# 1      5'-AMP-activated protein kinase subunit gamma-1    PRKAG1
# 2                                      Alpha-actinin-1     ACTN1
# 3                                          Protein Wnt    WNT10B
# 4                                                   Na        Na
# ..                                                 ...       ...
# 195                 Solute carrier family 26 member 10  SLC26A10
# 196          Rho guanine nucleotide exchange factor 25  ARHGEF25
# 197                        E3 ubiquitin-protein ligase     DTX3L
# 198  Phosphatidylinositol 5-phosphate 4-kinase type...   PIP4K2C
# 199                           Kinesin family member 5A     KIF5A
#
#                 Organism      Status  \
# 0                     Na          Na
# 1    Bos taurus (Bovine)    Reviewed
# 2    Bos taurus (Bovine)    Reviewed
# 3    Bos taurus (Bovine)  Unreviewed
# 4                     Na          Na
# ..                   ...         ...
# 195  Bos taurus (Bovine)  Unreviewed
# 196  Bos taurus (Bovine)  Unreviewed
# 197  Bos taurus (Bovine)  Unreviewed
# 198  Bos taurus (Bovine)    Reviewed
# 199  Bos taurus (Bovine)  Unreviewed
#
#                                  GO-Biological process
# 0                                                   Na
# 1    cellular response to glucose starvation.fatty ...
# 2    establishment of localization.regulation of AT...
# 3    bone trabecula formation.canonical Wnt signali...
# 4                                                   Na
# ..                                                 ...
# 195                                                 Na
# 196     regulation of Rho protein signal transduction.
# 197  double-strand break repair.endosome to lysosom...
# 198  1-phosphatidyl-1D-myo-inositol 4,5-bisphosphat...
# 199  anterograde dendritic transport of neurotransm...
#
# [200 rows x 8 columns]

# %%
### creación del excel
from pandas import ExcelWriter
writer = ExcelWriter('./Parte1.xlsx')
df.to_excel(writer, index=False)
writer.save()
