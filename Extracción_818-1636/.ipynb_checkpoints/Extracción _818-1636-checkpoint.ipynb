# %%
from bs4 import BeautifulSoup as soup
import requests
import urllib.request   
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
#Lectura de genes limpios(sin repetición)
df = pd.read_excel('Gen_abrev.xlsx',index_col=0, names=['N°','Gen abrev', 'Conteo'])
Datos = df["Gen abrev"]
datos= Datos.iloc[818:1636]
len(datos)
# Out:
# 818

# %%
lista_genes=[]
for i in range(len(datos)):
    lista_genes.append(datos.iloc[i])
lista_genes
# Out:
# ['MIR2426',
#  'PRKAG1',
#  'DDN',
#  'WNT10B',
#  'LOC112446681',
#  'ARF3',
#  'FKBP11',
#  'CCDC65',
#  'RND1',
#  'DDX23',
#  'CACNB3',
#  'ADCY6',
#  'TEX49',
#  'LOC107132475',
#  'CCNT1',
#  'KANSL2',
#  'LOC112446865',
#  'LOC112446866',
#  'MIR1291',
#  'LOC783895',
#  'LALBA',
#  'LOC104972406',
#  'LOC617415',
#  'LOC526630',
#  'LOC614370',
#  'LOC515887',
#  'OR8S27 LOC506992',
#  'OR8S25 LOC781446',
#  'OR8S10 LOC509508',
#  'LOC781517',
#  'OR8S15 LOC507383',
#  'LOC781595',
#  'OR8S1',
#  'OR8S24 LOC504567',
#  'LOC781756',
#  'LOC781840',
#  'LOC101907855',
#  'C5H12orf54',
#  'OR8S2 LOC509817',
#  'OR8S26 LOC781968',
#  'OR8S3 LOC617388',
#  'LOC617380',
#  'LOC518129',
#  'LOC100300010',
#  'OR5BJ2 LOC523258',
#  'LOC100848234',
#  'ZNF641',
#  'H1-7  LOC784038',
#  'H1FNT',
#  'LOC513452',
#  'LOC619137',
#  'LOC101902265',
#  'LOC101905376',
#  'LOC104972407',
#  'OR10AD1',
#  'CCDC184',
#  'LOC100139168',
#  'ASB8',
#  'PFKM',
#  'SENP1',
#  'COL2A1',
#  'TMEM106C',
#  'VDR',
#  'LOC101905514',
#  'LOC101905666',
#  'HDAC7',
#  'SLC48A1',
#  'LOC101905586',
#  'RAPGEF3',
#  'LOC112446799',
#  'ENDOU',
#  'RPAP3',
#  'LOC112446682',
#  'LOC101902438',
#  'LOC112446683',
#  'LOC112446684',
#  'LOC112446685',
#  'LOC107132477',
#  'PCED1B',
#  'LOC100847695',
#  'AMIGO2',
#  'LOC112446608',
#  'SLC38A4',
#  'LOC112446686',
#  'LOC107132478',
#  'LOC112446800',
#  'SLC38A2',
#  'SLC38A1',
#  'LOC112446688',
#  'SCAF11',
#  'ARID2',
#  'ANO6',
#  'LOC784769',
#  'DBX2',
#  'NELL2',
#  'LOC101906916',
#  'TMEM117',
#  'TWF1',
#  'IRAK4',
#  'PUS7L',
#  'ADAMTS20',
#  'LOC534627',
#  'LOC112446902',
#  'LOC786089',
#  'TRNAS-GGA',
#  'LOC112446856',
#  'LOC112446801',
#  'MUC19',
#  'LOC534391',
#  'LRRK2',
#  'SLC2A13',
#  'C5H12orf40',
#  'ABCD2',
#  'LOC785955',
#  'LOC100847470',
#  'KIF21A',
#  'MIR2428',
#  'LOC112446895',
#  'LOC617654',
#  'CPNE8',
#  'PTPRR',
#  'LOC112446905',
#  'LOC112446692',
#  'PTPRB',
#  'MIR2284Z-5',
#  'KCNMB4',
#  'LOC112446691',
#  'CNOT2',
#  'LOC107131684',
#  'LOC104972423',
#  'MYRFL',
#  'RAB3IP',
#  'LOC107132482',
#  'BEST3',
#  'LRRC10',
#  'CCT2',
#  'FRS2',
#  'MIR2427',
#  'LOC100138933',
#  'YEATS4',
#  'LYZ1',
#  'LOC112446887',
#  'LOC112446915',
#  'LOC785803',
#  'LOC781146',
#  'LOC112446693',
#  'LOC112446695',
#  'LOC112446889',
#  'LOC617219',
#  'LOC112446694',
#  'LOC112446890',
#  'LYSB',
#  'LYZ2',
#  'LYZ3',
#  'LOC787241',
#  'LOC112446907',
#  'LYZ',
#  'CPSF6',
#  'LOC107132485',
#  'LOC112446864',
#  'LOC104969823',
#  'CPM',
#  'LOC112446696',
#  'MDM2',
#  'SRGAP1',
#  'RXYLT1',
#  'AVPR1A',
#  'LOC100140195',
#  'PPM1H',
#  'LOC112446702',
#  'LOC104972443',
#  'LOC784406',
#  'MIRLET7I',
#  'MON2',
#  'USP15',
#  'FAM19A2',
#  'LOC101903699',
#  'LOC101904412',
#  'ATP23',
#  'LOC112446704',
#  'CTDSP2',
#  'MIR26A-2',
#  'AVIL',
#  'TSFM',
#  'EEF1AKMT3',
#  'METTL1',
#  'CYP27B1',
#  'MARCH9',
#  'CDK4',
#  'TSPAN31',
#  'AGAP2',
#  'LOC112446705',
#  'OS9',
#  'LOC112446803',
#  'B4GALNT1',
#  'SLC26A10',
#  'ARHGEF25',
#  'DTX3',
#  'PIP4K2C',
#  'KIF5A',
#  'DCTN2',
#  'MBD6',
#  'DDIT3',
#  'MARS',
#  'MIR2430',
#  'ARHGAP9',
#  'GLI1',
#  'INHBE',
#  'INHBC',
#  'R3HDM2',
#  'STAC3',
#  'LOC112446707',
#  'LOC112446706',
#  'NDUFA4L2',
#  'SHMT2',
#  'NXPH4',
#  'LRP1',
#  'LOC112446855',
#  'MIR2431',
#  'STAT6',
#  'LOC101902542',
#  'LOC100336976',
#  'NEMP1',
#  'MYO1A',
#  'TAC3',
#  'ZBTB39',
#  'GPR182',
#  'LOC100295935',
#  'LOC522844',
#  'LOC112446612',
#  'LOC100139075',
#  'LOC112446804',
#  'RDH16',
#  'SDR9C7',
#  'LOC100294910',
#  'LOC100138638',
#  'LOC112446873',
#  'LOC112446872',
#  'HSD17B6',
#  'PRIM1',
#  'NACA',
#  'LOC784846',
#  'PTGES3',
#  'ATP5F1B',
#  'LOC112446861',
#  'LOC112446708',
#  'MIR677',
#  'BAZ2A',
#  'RBMS2',
#  'GLS2',
#  'SPRYD4',
#  'MIP',
#  'TIMELESS',
#  'ApoN',
#  'STAT2',
#  'IL23A',
#  'MIR2432',
#  'LOC107132490',
#  'CNPY2',
#  'CS',
#  'LOC112446709',
#  'COQ10A',
#  'ANKRD52',
#  'MIR2433',
#  'NABP2',
#  'RNF41',
#  'LOC112446710',
#  'TRNAS-CGA',
#  'MYL6',
#  'MYL6B',
#  'LOC112446711',
#  'ESYT1',
#  'LOC101903253',
#  'ZC3H10',
#  'PA2G4',
#  'ERBB3',
#  'RPS26',
#  'IKZF4',
#  'SUOX',
#  'RAB5B',
#  'CDK2',
#  'PMEL',
#  'DGKA',
#  'PYM1',
#  'LOC107132498',
#  'MMP19',
#  'LOC507581',
#  'DNAJC14',
#  'ORMDL2',
#  'SARNP',
#  'GDF11',
#  'LOC101903534',
#  'CD63',
#  'RDH5',
#  'BLOC1S1',
#  'ITGA7',
#  'METTL7B',
#  'LOC520938',
#  'LOC112446881',
#  'OR10P1',
#  'OR6C4',
#  'LOC112446805',
#  'LOC781363',
#  'OR2AP1',
#  'LOC101903758',
#  'LOC100847112',
#  'LOC615284',
#  'LOC618816',
#  'LOC506139',
#  'LOC526713',
#  'LOC782840',
#  'LOC510046',
#  'LOC112446806',
#  'LOC529303',
#  'LOC782659',
#  'LOC782624',
#  'LOC782591',
#  'LOC782550',
#  'LOC112446906',
#  'LOC100140445',
#  'GAS2L3',
#  'LOC112446714',
#  'LOC112446715',
#  'LOC112446713',
#  'ANO4',
#  'MIR2434',
#  'LOC101905784',
#  'SLC5A8',
#  'LOC101908204',
#  'UTP20',
#  'ARL1',
#  'LOC101902002',
#  'SPIC',
#  'MYBPC1',
#  'CHPT1',
#  'LOC112446716',
#  'SYCP3',
#  'GNPTAB',
#  'LOC101902154',
#  'DRAM1',
#  'LOC782673',
#  'LOC104972477',
#  'WASHC3',
#  'NUP37',
#  'LOC101904077',
#  'PARPBP',
#  'PMCH',
#  'LOC112446820',
#  'LOC783823',
#  'LOC112446717',
#  'IGF1',
#  'LOC112446897',
#  'LOC101902701',
#  'LOC112446839',
#  'PAH',
#  'ASCL1',
#  'LOC101906016',
#  'LOC112446884',
#  'LOC112446615',
#  'C5H12orf42',
#  'STAB2',
#  'NT5DC3',
#  'LOC505479',
#  'HSP90B1',
#  'C5H12orf73',
#  'TDG',
#  'GLT8D2',
#  'HCFC2',
#  'NFYB',
#  'MIR2435',
#  'TRNAA-UGC',
#  'LOC101906262',
#  'EID3',
#  'LOC112446721',
#  'CHST11',
#  'LOC112446720',
#  'SLC41A2',
#  'C5H12orf45',
#  'ALDH1L2',
#  'LOC786352',
#  'LOC515697',
#  'LOC518495',
#  'LOC788334',
#  'LOC524576',
#  'LOC112446725',
#  'APOL3',
#  'LOC112446726',
#  'LOC619179',
#  'LOC101906044',
#  'MYH9',
#  'LOC112446616',
#  'LOC112446838',
#  'TXN2',
#  'FOXRED2',
#  'EIF3D',
#  'CACNG2',
#  'IFT27',
#  'LOC101906435',
#  'PVALB',
#  'NCF4',
#  'CSF2RB',
#  'LOC788541',
#  'TEX33',
#  'TST',
#  'MPST',
#  'KCTD17',
#  'TMPRSS6',
#  'IL2RB',
#  'LOC510185',
#  'C1QTNF6',
#  'LOC112446727',
#  'SSTR3',
#  'RAC2',
#  'MIR1835',
#  'CYTH4',
#  'ELFN2',
#  'MFNG',
#  'CARD10',
#  'LOC112446845',
#  'LOC112446901',
#  'USP18',
#  'ALG10',
#  'KLHL42',
#  'MANSC4',
#  'MRPS35',
#  'LOC781532',
#  'REP15',
#  'PPFIBP1',
#  'C5H12orf71',
#  'LOC781688',
#  'SMCO2',
#  'LOC112446918',
#  'ARNTL2',
#  'STK38L',
#  'MED21',
#  'TM7SF3',
#  'FGFR1OP2',
#  'INTS13',
#  'LOC112446618',
#  'LOC112446733',
#  'ITPR2',
#  'SSPN',
#  'LOC107132515',
#  'BHLHE41',
#  'MIR2436',
#  'LOC112446734',
#  'LMNTD1',
#  'KRAS',
#  'LOC104972526',
#  'ETFRF1',
#  'CASC1',
#  'LRMP',
#  'LOC112446824',
#  'BCAT1',
#  'LOC100295631',
#  'SOX5',
#  'ETNK1',
#  'C2CD5',
#  'ST8SIA1',
#  'LOC112446735',
#  'LOC112446736',
#  'CMAS',
#  'ABCC9',
#  'KCNJ8',
#  'GYS2',
#  'SPX',
#  'GOLT1B',
#  'RECQL',
#  'PYROXD1',
#  'SLCO1A2',
#  'IAPP',
#  'SLCO1B3',
#  'LOC101905711',
#  'LOC112446909',
#  'SLCO1C1',
#  'PDE3A',
#  'LMO3',
#  'LOC618358',
#  'MGST1',
#  'SLC15A5',
#  'DERA',
#  'LOC338087',
#  'STRAP',
#  'LOC112446862',
#  'EPS8',
#  'PTPRO',
#  'RERG',
#  'LOC112446622',
#  'PDE6H',
#  'ARHGDIB',
#  'ERP27',
#  'MGP',
#  'ART4',
#  'SMCO3',
#  'C5H12orf60',
#  'WBP11',
#  'H2AFJ',
#  'LOC530773',
#  'GUCY2C',
#  'PLBD1',
#  'LOC504273',
#  'LOC100139276',
#  'ATF7IP',
#  'LOC112446913',
#  'LOC100139060',
#  'GRIN2B',
#  'TAS2R8',
#  'LOC104972542',
#  'YBX3',
#  'MAGOHB',
#  'KLRA1',
#  'LOC101902742',
#  'LOC101902704',
#  'LOC513869',
#  'LOC788694',
#  'LOC100140174',
#  'LOC112446743',
#  'KLRC1',
#  'LOC101904370',
#  'LOC104970137',
#  'LOC100847738',
#  'LOC101905165',
#  'LOC100336869',
#  'LOC101904903',
#  'KLRJ1',
#  'LOC100296778',
#  'LOC101905403',
#  'NKG2A',
#  'NKG2C',
#  'LOC100847813',
#  'KLRK1',
#  'KLRD1',
#  'LOC618565',
#  'LOC100848575',
#  'GABARAPL1',
#  'TMEM52B',
#  'OLR1',
#  'CLEC7A',
#  'CLEC1A',
#  'CLEC9A',
#  'CLEC1B',
#  'CLEC12B',
#  'CLEC12A',
#  'LOC785168',
#  'LOC784329',
#  'LOC100847268',
#  'KLRF2',
#  'CLEC2B',
#  'LOC617565',
#  'LOC509972',
#  'LOC784451',
#  'LOC101905748',
#  'LOC104972552',
#  'KLRF1',
#  'LOC101905801',
#  'CD69',
#  'LOC100294723',
#  'LOC107132519',
#  'LOC112446891',
#  'LOC100297676',
#  'LOC112446744',
#  'LOC104972545',
#  'LOC100297770',
#  'LOC100138381',
#  'OVOS2',
#  'LOC112446837',
#  'LOC506828',
#  'WC1.3',
#  'WC1',
#  'WC1-8',
#  'CD163L1',
#  'PEX5',
#  'CLSTN3',
#  'RBP5',
#  'C1RL',
#  'C1R',
#  'C1S',
#  'LPCAT3',
#  'EMG1',
#  'PHB2',
#  'MIR141',
#  'MIR200C',
#  'PTPN6',
#  'C5H12orf57',
#  'ATN1',
#  'ENO2',
#  'LRRC23',
#  'SPSB2',
#  'TPI1',
#  'USP5',
#  'CDCA3',
#  'GNB3',
#  'GPR162',
#  'CD4',
#  'LAG3',
#  'PTMS',
#  'MLF2',
#  'COPS7A',
#  'PIANP',
#  'ZNF384',
#  'ING4',
#  'ACRBP',
#  'LPAR5',
#  'CHD4',
#  'NOP2',
#  'IFFO1',
#  'GAPDH',
#  'NCAPD2',
#  'MIR2424',
#  'MRPL51',
#  'VAMP1',
#  'TAPBPL',
#  'CD27',
#  'LTBR',
#  'SCNN1A',
#  'TNFRSF1A',
#  'PLEKHG6',
#  'CD9',
#  'VWF',
#  'LOC112446761',
#  'ANO2',
#  'LOC100297751',
#  'NTF3',
#  'LOC104972566',
#  'LOC112446625',
#  'LOC112446626',
#  'KCNA5',
#  'KCNA1',
#  'KCNA6',
#  'GALNT8',
#  'NDUFA9',
#  'DYRK4',
#  'RAD51AP1',
#  'LOC100336013',
#  'FGF6',
#  'FGF23',
#  'LOC112446763',
#  'TIGAR',
#  'CCND2',
#  'LOC104972567',
#  'LOC107132523',
#  'LOC112446627',
#  'PARP11',
#  'CRACR2A',
#  'PRMT8',
#  'LOC100847686',
#  'LOC112446764',
#  'TSPAN11',
#  'TSPAN9',
#  'LOC101902968',
#  'LOC104972568',
#  'TEAD4',
#  'TULP3',
#  'RHNO1',
#  'FOXM1',
#  'LOC104972569',
#  'TEX52',
#  'NRIP2',
#  'ITFG2',
#  'FKBP4',
#  'DDX11',
#  'WASHC1',
#  'IQSEC3',
#  'LOC104972570',
#  'SLC6A12',
#  'LOC112446765',
#  'SLC6A13',
#  'KDM5A',
#  'LOC781777',
#  'CCDC77',
#  'B4GALNT3',
#  'LOC112446858',
#  'NINJ2',
#  'LOC104972574',
#  'LOC112446767',
#  'LOC112446903',
#  'MIR2437',
#  'LOC112446768',
#  'WNK1',
#  'RAD52',
#  'ERC1',
#  'LOC112446770',
#  'LOC112446769',
#  'WNT5B',
#  'FBXL14',
#  'ADIPOR2',
#  'LOC104972578',
#  'CACNA2D4',
#  'LRTM2',
#  'DCP1B',
#  'CACNA1C',
#  'TRNAY-GUA',
#  'LOC104970340',
#  'TMEM121B',
#  'HDHD5',
#  'ADA2',
#  'LOC104970683',
#  'CECR2',
#  'LOC112446914',
#  'BCL2L13',
#  'LOC104972584',
#  'BID',
#  'LOC104972586',
#  'SH3BP1',
#  'PDXP',
#  'LOC100847870',
#  'LGALS1',
#  'NOL12',
#  'MIR2438',
#  'TRIOBP',
#  'H1F0',
#  'GCAT',
#  'GALR3',
#  'ANKRD54',
#  'MIR658',
#  'EIF3L',
#  'MICALL1',
#  'C5H22orf23',
#  'POLR2F',
#  'SOX10',
#  'LOC101905166',
#  'PICK1',
#  'SLC16A8',
#  'BAIAP2L2',
#  'PLA2G6',
#  'MAFF',
#  'TMEM184B',
#  'CSNK1E',
#  'KCNJ4',
#  'KDELR3',
#  'DDX17',
#  'DMC1',
#  'FAM227A',
#  'LOC112446908',
#  'CBY1',
#  'TOMM22',
#  'JOSD1',
#  'GTPBP1',
#  'SUN2',
#  'DNAL4',
#  'NPTXR',
#  'CBX6',
#  'ADSL',
#  'SGSM3',
#  'MKL1',
#  'MIR2439',
#  'MCHR1',
#  'SLC25A17',
#  'ST13',
#  'XPNPEP3',
#  'DNAJB7',
#  'RBX1',
#  'MIR1281',
#  'EP300',
#  'L3MBTL2',
#  'MIR2441',
#  'CHADL',
#  'RANGAP1',
#  'ZC3H7B',
#  'TEF',
#  'TOB2',
#  'PHF5A',
#  'ACO2',
#  'POLR3H',
#  'TRNAM-CAU',
#  'CSDC2',
#  'PMM1',
#  'DESI1',
#  'XRCC6',
#  'SNU13',
#  'C5H22orf46',
#  'MEI1',
#  'CCDC134',
#  'SREBF2',
#  'MIR33A',
#  'SHISA8',
#  'TNFRSF13C',
#  'CENPM',
#  'SEPT3',
#  'WBP2NL',
#  'NAGA',
#  'PHETA2',
#  'SMDT1',
#  'NDUFA6',
#  'MGC127055',
#  'CYP2D14',
#  'MIR2442',
#  'TCF20',
#  'NFAM1',
#  'SERHL2',
#  'RRP7A',
#  'POLDIP3',
#  'CYB5R3',
#  'A4GALT',
#  'TACR3',
#  'CENPE',
#  'BDH2',
#  'SLC9B2',
#  'NHEDC1',
#  'CISD2',
#  'UBE2D3',
#  'MANBA',
#  'NFKB1',
#  'SLC39A8',
#  'GPRIN3',
#  'TIGD2',
#  'FAM13A',
#  'LOC104972724',
#  'HERC3',
#  'LOC100847719',
#  'NAP1L5',
#  'PIGY',
#  'PYURF',
#  'HERC5',
#  'HERC6',
#  'PPM1K',
#  'ABCG2',
#  'LOC112447205']

# %%
#para crear los links correspondientess de busqueda tenemos que hacer una modificaciones
lista=[]
for genes in lista_genes:
#len(Datos.iloc[818:1637])
    lista.append(genes.replace(" ", "+"))
#print(lista)

lista1=[]
for genes in lista:
    lista1.append(genes.replace("(","%28"))
#print(lista1)

query=[]
for genes in lista1:
    query.append(genes.replace(")","%29"))
print(query)
len(query)
# Out:
# ['MIR2426', 'PRKAG1', 'DDN', 'WNT10B', 'LOC112446681', 'ARF3', 'FKBP11', 'CCDC65', 'RND1', 'DDX23', 'CACNB3', 'ADCY6', 'TEX49', 'LOC107132475', 'CCNT1', 'KANSL2', 'LOC112446865', 'LOC112446866', 'MIR1291', 'LOC783895', 'LALBA', 'LOC104972406', 'LOC617415', 'LOC526630', 'LOC614370', 'LOC515887', 'OR8S27+LOC506992', 'OR8S25+LOC781446', 'OR8S10+LOC509508', 'LOC781517', 'OR8S15+LOC507383', 'LOC781595', 'OR8S1', 'OR8S24+LOC504567', 'LOC781756', 'LOC781840', 'LOC101907855', 'C5H12orf54', 'OR8S2+LOC509817', 'OR8S26+LOC781968', 'OR8S3+LOC617388', 'LOC617380', 'LOC518129', 'LOC100300010', 'OR5BJ2+LOC523258', 'LOC100848234', 'ZNF641', 'H1-7++LOC784038', 'H1FNT', 'LOC513452', 'LOC619137', 'LOC101902265', 'LOC101905376', 'LOC104972407', 'OR10AD1', 'CCDC184', 'LOC100139168', 'ASB8', 'PFKM', 'SENP1', 'COL2A1', 'TMEM106C', 'VDR', 'LOC101905514', 'LOC101905666', 'HDAC7', 'SLC48A1', 'LOC101905586', 'RAPGEF3', 'LOC112446799', 'ENDOU', 'RPAP3', 'LOC112446682', 'LOC101902438', 'LOC112446683', 'LOC112446684', 'LOC112446685', 'LOC107132477', 'PCED1B', 'LOC100847695', 'AMIGO2', 'LOC112446608', 'SLC38A4', 'LOC112446686', 'LOC107132478', 'LOC112446800', 'SLC38A2', 'SLC38A1', 'LOC112446688', 'SCAF11', 'ARID2', 'ANO6', 'LOC784769', 'DBX2', 'NELL2', 'LOC101906916', 'TMEM117', 'TWF1', 'IRAK4', 'PUS7L', 'ADAMTS20', 'LOC534627', 'LOC112446902', 'LOC786089', 'TRNAS-GGA', 'LOC112446856', 'LOC112446801', 'MUC19', 'LOC534391', 'LRRK2', 'SLC2A13', 'C5H12orf40', 'ABCD2', 'LOC785955', 'LOC100847470', 'KIF21A', 'MIR2428', 'LOC112446895', 'LOC617654', 'CPNE8', 'PTPRR', 'LOC112446905', 'LOC112446692', 'PTPRB', 'MIR2284Z-5', 'KCNMB4', 'LOC112446691', 'CNOT2', 'LOC107131684', 'LOC104972423', 'MYRFL', 'RAB3IP', 'LOC107132482', 'BEST3', 'LRRC10', 'CCT2', 'FRS2', 'MIR2427', 'LOC100138933', 'YEATS4', 'LYZ1', 'LOC112446887', 'LOC112446915', 'LOC785803', 'LOC781146', 'LOC112446693', 'LOC112446695', 'LOC112446889', 'LOC617219', 'LOC112446694', 'LOC112446890', 'LYSB', 'LYZ2', 'LYZ3', 'LOC787241', 'LOC112446907', 'LYZ', 'CPSF6', 'LOC107132485', 'LOC112446864', 'LOC104969823', 'CPM', 'LOC112446696', 'MDM2', 'SRGAP1', 'RXYLT1', 'AVPR1A', 'LOC100140195', 'PPM1H', 'LOC112446702', 'LOC104972443', 'LOC784406', 'MIRLET7I', 'MON2', 'USP15', 'FAM19A2', 'LOC101903699', 'LOC101904412', 'ATP23', 'LOC112446704', 'CTDSP2', 'MIR26A-2', 'AVIL', 'TSFM', 'EEF1AKMT3', 'METTL1', 'CYP27B1', 'MARCH9', 'CDK4', 'TSPAN31', 'AGAP2', 'LOC112446705', 'OS9', 'LOC112446803', 'B4GALNT1', 'SLC26A10', 'ARHGEF25', 'DTX3', 'PIP4K2C', 'KIF5A', 'DCTN2', 'MBD6', 'DDIT3', 'MARS', 'MIR2430', 'ARHGAP9', 'GLI1', 'INHBE', 'INHBC', 'R3HDM2', 'STAC3', 'LOC112446707', 'LOC112446706', 'NDUFA4L2', 'SHMT2', 'NXPH4', 'LRP1', 'LOC112446855', 'MIR2431', 'STAT6', 'LOC101902542', 'LOC100336976', 'NEMP1', 'MYO1A', 'TAC3', 'ZBTB39', 'GPR182', 'LOC100295935', 'LOC522844', 'LOC112446612', 'LOC100139075', 'LOC112446804', 'RDH16', 'SDR9C7', 'LOC100294910', 'LOC100138638', 'LOC112446873', 'LOC112446872', 'HSD17B6', 'PRIM1', 'NACA', 'LOC784846', 'PTGES3', 'ATP5F1B', 'LOC112446861', 'LOC112446708', 'MIR677', 'BAZ2A', 'RBMS2', 'GLS2', 'SPRYD4', 'MIP', 'TIMELESS', 'ApoN', 'STAT2', 'IL23A', 'MIR2432', 'LOC107132490', 'CNPY2', 'CS', 'LOC112446709', 'COQ10A', 'ANKRD52', 'MIR2433', 'NABP2', 'RNF41', 'LOC112446710', 'TRNAS-CGA', 'MYL6', 'MYL6B', 'LOC112446711', 'ESYT1', 'LOC101903253', 'ZC3H10', 'PA2G4', 'ERBB3', 'RPS26', 'IKZF4', 'SUOX', 'RAB5B', 'CDK2', 'PMEL', 'DGKA', 'PYM1', 'LOC107132498', 'MMP19', 'LOC507581', 'DNAJC14', 'ORMDL2', 'SARNP', 'GDF11', 'LOC101903534', 'CD63', 'RDH5', 'BLOC1S1', 'ITGA7', 'METTL7B', 'LOC520938', 'LOC112446881', 'OR10P1', 'OR6C4', 'LOC112446805', 'LOC781363', 'OR2AP1', 'LOC101903758', 'LOC100847112', 'LOC615284', 'LOC618816', 'LOC506139', 'LOC526713', 'LOC782840', 'LOC510046', 'LOC112446806', 'LOC529303', 'LOC782659', 'LOC782624', 'LOC782591', 'LOC782550', 'LOC112446906', 'LOC100140445', 'GAS2L3', 'LOC112446714', 'LOC112446715', 'LOC112446713', 'ANO4', 'MIR2434', 'LOC101905784', 'SLC5A8', 'LOC101908204', 'UTP20',  ...
# 818

# %%
LISTA_GENES= query[400:600]
print(LISTA_GENES)
len(LISTA_GENES)
# Out:
# ['CSF2RB', 'LOC788541', 'TEX33', 'TST', 'MPST', 'KCTD17', 'TMPRSS6', 'IL2RB', 'LOC510185', 'C1QTNF6', 'LOC112446727', 'SSTR3', 'RAC2', 'MIR1835', 'CYTH4', 'ELFN2', 'MFNG', 'CARD10', 'LOC112446845', 'LOC112446901', 'USP18', 'ALG10', 'KLHL42', 'MANSC4', 'MRPS35', 'LOC781532', 'REP15', 'PPFIBP1', 'C5H12orf71', 'LOC781688', 'SMCO2', 'LOC112446918', 'ARNTL2', 'STK38L', 'MED21', 'TM7SF3', 'FGFR1OP2', 'INTS13', 'LOC112446618', 'LOC112446733', 'ITPR2', 'SSPN', 'LOC107132515', 'BHLHE41', 'MIR2436', 'LOC112446734', 'LMNTD1', 'KRAS', 'LOC104972526', 'ETFRF1', 'CASC1', 'LRMP', 'LOC112446824', 'BCAT1', 'LOC100295631', 'SOX5', 'ETNK1', 'C2CD5', 'ST8SIA1', 'LOC112446735', 'LOC112446736', 'CMAS', 'ABCC9', 'KCNJ8', 'GYS2', 'SPX', 'GOLT1B', 'RECQL', 'PYROXD1', 'SLCO1A2', 'IAPP', 'SLCO1B3', 'LOC101905711', 'LOC112446909', 'SLCO1C1', 'PDE3A', 'LMO3', 'LOC618358', 'MGST1', 'SLC15A5', 'DERA', 'LOC338087', 'STRAP', 'LOC112446862', 'EPS8', 'PTPRO', 'RERG', 'LOC112446622', 'PDE6H', 'ARHGDIB', 'ERP27', 'MGP', 'ART4', 'SMCO3', 'C5H12orf60', 'WBP11', 'H2AFJ', 'LOC530773', 'GUCY2C', 'PLBD1', 'LOC504273', 'LOC100139276', 'ATF7IP', 'LOC112446913', 'LOC100139060', 'GRIN2B', 'TAS2R8', 'LOC104972542', 'YBX3', 'MAGOHB', 'KLRA1', 'LOC101902742', 'LOC101902704', 'LOC513869', 'LOC788694', 'LOC100140174', 'LOC112446743', 'KLRC1', 'LOC101904370', 'LOC104970137', 'LOC100847738', 'LOC101905165', 'LOC100336869', 'LOC101904903', 'KLRJ1', 'LOC100296778', 'LOC101905403', 'NKG2A', 'NKG2C', 'LOC100847813', 'KLRK1', 'KLRD1', 'LOC618565', 'LOC100848575', 'GABARAPL1', 'TMEM52B', 'OLR1', 'CLEC7A', 'CLEC1A', 'CLEC9A', 'CLEC1B', 'CLEC12B', 'CLEC12A', 'LOC785168', 'LOC784329', 'LOC100847268', 'KLRF2', 'CLEC2B', 'LOC617565', 'LOC509972', 'LOC784451', 'LOC101905748', 'LOC104972552', 'KLRF1', 'LOC101905801', 'CD69', 'LOC100294723', 'LOC107132519', 'LOC112446891', 'LOC100297676', 'LOC112446744', 'LOC104972545', 'LOC100297770', 'LOC100138381', 'OVOS2', 'LOC112446837', 'LOC506828', 'WC1.3', 'WC1', 'WC1-8', 'CD163L1', 'PEX5', 'CLSTN3', 'RBP5', 'C1RL', 'C1R', 'C1S', 'LPCAT3', 'EMG1', 'PHB2', 'MIR141', 'MIR200C', 'PTPN6', 'C5H12orf57', 'ATN1', 'ENO2', 'LRRC23', 'SPSB2', 'TPI1', 'USP5', 'CDCA3', 'GNB3', 'GPR162', 'CD4', 'LAG3', 'PTMS', 'MLF2', 'COPS7A', 'PIANP', 'ZNF384']
# 200

# %%
links=[]

for i in query:
    links.append("https://www.uniprot.org/uniprot/?query="+ str(i) + "+Bos+taurus&sort=score")
#print(links)

# %%
len(links)
# Out:
# 818

# %% [markdown]
# ### TERCERA EXTRACCIÓN DE LOS 200 siguientes LINKS [400-600]

# %%
####################
# COLUMNA2 ENTRY 
####################


import urllib.request, urllib.parse, urllib.error #(solicitud,analizar,error)
import re
import ssl  
ctx = ssl.create_default_context()                    #crear un contexto predeterminado
ctx.check_hostname = False                            #comprobar el nombre de host
ctx.verify_mode = ssl.CERT_NONE                       #modo de verificación

LISTA_ENTRY = []

for codigo in links[400:600]:
    url = codigo
    html = urllib.request.urlopen(url, context=ctx).read()  
    link = re.findall(b'<a href=".uniprot.([a-zA-Z].*?)"', html) 
    if len(link)==0:
        LISTA_ENTRY.append("Na")
    else:
        objeto=link[0].decode()
        LISTA_ENTRY = LISTA_ENTRY +[objeto] 
print(LISTA_ENTRY)   
len(LISTA_ENTRY)
# Out:
# ['Q9BDR7', 'Na', 'Q32LI7', 'P00586', 'A0A3Q1M9D2', 'F1MWW3', 'F1MWW8', 'Q28028', 'Na', 'F1MGK1', 'Na', 'P34993', 'Q9TU25', 'Na', 'Q3T0M9', 'F1MWA2', 'Q1LZD7', 'F1MW90', 'Na', 'Na', 'A0A3Q1MCA9', 'O18965', 'F1MAX6', 'G3MZR6', 'Q2YDF6', 'Na', 'Q1RMR4', 'P35466', 'F1MF69', 'Na', 'A0A4W2DY46', 'Na', 'Q5EA15', 'F1MH07', 'A0A3Q1MIU0', 'A0A4W2F002', 'A0A3Q1M7M7', 'Q2KIB1', 'Na', 'Na', 'Q8WN96', 'E1BKV5', 'Na', 'Q5EA15', 'Na', 'Na', 'A0A4W2EYZ9', 'P32871', 'Na', 'P52505', 'Q29RU8', 'Na', 'Na', 'A0A3Q1ML78', 'Na', 'A0A3Q1MR44', 'F1N378', 'A0A4W2EYH9', 'Q6ZXD2', 'Na', 'Na', 'Q3SZM5', 'E1B8L0', 'Q2KHY6', 'E1B9X7', 'Q0VC44', 'Q2YDE3', 'Q2KJ94', 'A7YVH9', 'A0A3Q1N7T3', 'Q24K02', 'F1MYV0', 'Na', 'Na', 'E1BC23', 'O46382', 'Q2KIA3', 'Na', 'Q64L89', 'F1N3P6', 'P67808', 'Na', 'P67939', 'Na', 'E1BCX9', 'A0JNB0', 'Q0VCJ7', 'Na', 'P22571', 'P61585', 'Q32L47', 'Q95114', 'G3N030', 'E1BAP9', 'E1BFQ7', 'Q2HJC9', 'Na', 'Na', 'F1N5B2', 'Q9GL30', 'Na', 'Na', 'Q1RMT1', 'Na', 'Na', 'P28291', 'A0A3Q1LZA1', 'Na', 'A0A3Q1LIJ0', 'Q2NL22', 'Q8SPQ6', 'Na', 'Na', 'F1MHY4', 'Na', 'A0A3Q1NM98', 'Na', 'Q863H3', 'Na', 'Na', 'G3X7N3', 'Na', 'A3R3B5', 'Na', 'Q863I0', 'A0A3Q1MLG6', 'A0A3Q1MHA6', 'A3R3B5', 'F1MPK9', 'Na', 'Q1XF11', 'Q863H3', 'A0A3Q1LP11', 'E1B977', 'Q8HYB6', 'A7YY71', 'P79391', 'Q49BZ4', 'Q0VCS6', 'A0A4W2FMD4', 'P63243', 'Q2NL33', 'Q2NL33', 'A0A3Q1MLL0', 'Na', 'Na', 'G3N2I5', 'A0A3Q1MHL8', 'F1ME19', 'A0A3Q1LRJ4', 'E1BH08', 'Na', 'Na', 'A5PJG8', 'Na', 'Q5EA90', 'A0A3Q1MUA5', 'Na', 'Na', 'G3MX70', 'Na', 'Na', 'Na', 'Na', 'F1MB90', 'Na', 'F1MJK3', 'A0A3Q1MPU0', 'Q0IIE2', 'E3W9A0', 'A0A3Q1NNS6', 'Q1RMV0', 'Q0VCN6', 'P82708', 'F1N1S6', 'P00760', 'Q0VCX1', 'Q3SZL3', 'F1N532', 'Q2HJ97', 'Na', 'Na', 'A0A3Q1M739', 'Na', 'Q2HJC9', 'A6QR19', 'Q32KP2', 'Q769I5', 'Q5E956', 'F1N3P2', 'A0A4W2C620', 'P0C7Q4', 'A0A4W2C8L3', 'F1MJK4', 'Q10741', 'P08814', 'F1MYV8', 'Q5E981', 'A4IFJ4', 'A0A3Q1M8T6']
# 200

# %%
############################
# COLUMNA3 ENTRY NAME 
############################

LISTA_ENTRYNAME = []

for codigo in links[400:600]:
    url = codigo
    html = urllib.request.urlopen(url, context=ctx).read()  
    link = re.findall(b'<td>([A-Z].*?)<.td>', html) 
    if len(link)==0:
        LISTA_ENTRYNAME.append('Na')
    else:
        objeto=link[0].decode()
        LISTA_ENTRYNAME=LISTA_ENTRYNAME +[objeto] 
print(LISTA_ENTRYNAME)    
len(LISTA_ENTRYNAME)
# Out:
# ['FCERG_BOVIN', 'Na', 'Q32LI7_BOVIN', 'THTR_BOVIN', 'A0A3Q1M9D2_BOVIN', 'F1MWW3_BOVIN', 'F1MWW8_BOVIN', 'IL15_BOVIN', 'Na', 'F1MGK1_BOVIN', 'Na', 'SSR2_BOVIN', 'RAC2_BOVIN', 'Na', 'ARL4A_BOVIN', 'F1MWA2_BOVIN', 'Q1LZD7_BOVIN', 'F1MW90_BOVIN', 'Na', 'Na', 'A0A3Q1MCA9_BOVIN', 'KCNH1_BOVIN', 'F1MAX6_BOVIN', 'G3MZR6_BOVIN', 'RT35_BOVIN', 'Na', 'RAB15_BOVIN', 'S10A4_BOVIN', 'F1MF69_BOVIN', 'Na', 'A0A4W2DY46_BOBOX', 'Na', 'BHE40_BOVIN', 'MICA1_BOVIN', 'A0A3Q1MIU0_BOVIN', 'A0A4W2F002_BOBOX', 'A0A3Q1M7M7_BOVIN', 'Q2KIB1_BOVIN', 'Na', 'Na', 'ITPR2_BOVIN', 'E1BKV5_BOVIN', 'Na', 'BHE40_BOVIN', 'Na', 'Na', 'A0A4W2EYZ9_BOBOX', 'PK3CA_BOVIN', 'Na', 'ACPM_BOVIN', 'CASC1_BOVIN', 'Na', 'Na', 'A0A3Q1ML78_BOVIN', 'Na', 'A0A3Q1MR44_BOVIN', 'F1N378_BOVIN', 'A0A4W2EYH9_BOBOX', 'SIA8A_BOVIN', 'Na', 'Na', 'NEUA_BOVIN', 'E1B8L0_BOVIN', 'Q2KHY6_BOVIN', 'E1B9X7_BOVIN', 'SPXN_BOVIN', 'GOT1B_BOVIN', 'RAD51_BOVIN', 'PYRD1_BOVIN', 'A0A3Q1N7T3_BOVIN', 'IDE_BOVIN', 'F1MYV0_BOVIN', 'Na', 'Na', 'E1BC23_BOVIN', 'BIG1_BOVIN', 'LMO3_BOVIN', 'Na', 'MGST1_BOVIN', 'F1N3P6_BOVIN', 'YBOX1_BOVIN', 'Na', 'P53_BOVIN', 'Na', 'E1BCX9_BOVIN', 'FYN_BOVIN', 'RERG_BOVIN', 'Na', 'CNCG_BOVIN', 'RHOA_BOVIN', 'ERP27_BOVIN', 'MFGM_BOVIN', 'G3N030_BOVIN', 'E1BAP9_BOVIN', 'E1BFQ7_BOVIN', 'PQBP1_BOVIN', 'Na', 'Na', 'F1N5B2_BOVIN', 'PLBL1_BOVIN', 'Na', 'Na', 'ERCC3_BOVIN', 'Na', 'Na', 'CCL2_BOVIN', 'A0A3Q1LZA1_BOVIN', 'Na', 'A0A3Q1LIJ0_BOVIN', 'IF4A3_BOVIN', 'Q8SPQ6_BOVIN', 'Na', 'Na', 'F1MHY4_BOVIN', 'Na', 'A0A3Q1NM98_BOVIN', 'Na', 'KLRD1_BOVIN', 'Na', 'Na', 'G3X7N3_BOVIN', 'Na', 'A3R3B5_BOVIN', 'Na', 'Q863I0_BOVIN', 'A0A3Q1MLG6_BOVIN', 'A0A3Q1MHA6_BOVIN', 'A3R3B5_BOVIN', 'F1MPK9_BOVIN', 'Na', 'HCST_BOVIN', 'KLRD1_BOVIN', 'A0A3Q1LP11_BOVIN', 'E1B977_BOVIN', 'GBRL1_BOVIN', 'A7YY71_BOVIN', 'OLR1_BOVIN', 'CLC7A_BOVIN', 'CLC1A_BOVIN', 'A0A4W2FMD4_BOBOX', 'RACK1_BOVIN', 'CL12B_BOVIN', 'CL12B_BOVIN', 'A0A3Q1MLL0_BOVIN', 'Na', 'Na', 'G3N2I5_BOVIN', 'A0A3Q1MHL8_BOVIN', 'F1ME19_BOVIN', 'A0A3Q1LRJ4_BOVIN', 'E1BH08_BOVIN', 'Na', 'Na', 'A5PJG8_BOVIN', 'Na', 'T106A_BOVIN', 'A0A3Q1MUA5_BOVIN', 'Na', 'Na', 'G3MX70_BOVIN', 'Na', 'Na', 'Na', 'Na', 'F1MB90_BOVIN', 'Na', 'F1MJK3_BOVIN', 'A0A3Q1MPU0_BOVIN', 'SHC1_BOVIN', 'E3W9A0_BOVIN', 'A0A3Q1NNS6_BOVIN', 'PEX5_BOVIN', 'CSTN3_BOVIN', 'RET5_BOVIN', 'F1N1S6_BOVIN', 'TRY1_BOVIN', 'C1S_BOVIN', 'MBOA5_BOVIN', 'F1N532_BOVIN', 'PHB2_BOVIN', 'Na', 'Na', 'A0A3Q1M739_BOVIN', 'Na', 'PQBP1_BOVIN', 'A6QR19_BOVIN', 'LRC23_BOVIN', 'MET_BOVIN', 'TPIS_BOVIN', 'F1N3P2_BOVIN', 'A0A4W2C620_BOBOX', 'GNAT3_BOVIN', 'A0A4W2C8L3_BOBOX', 'F1MJK4_BOVIN', 'ADA10_BOVIN', 'PTMS_BOVIN', 'F1MYV8_BOVIN', 'ID3_BOVIN', 'A4IFJ4_BOVIN', 'A0A3Q1M8T6_BOVIN']
# 200

# %%
urls=[]
for i in LISTA_ENTRY:
    if i=="Na":
        urls.append(0)
    else:
        urls.append("https://www.uniprot.org/uniprot/"+str(i))
#print(urls)
len(urls)
# Out:
# 200

# %%
###########################################
# COLUMNA4 PROTEIN  
###########################################


PROTEINA1=[]

for i in urls[0:33]:
    #print(i)
    if i==0:
        PROTEINA1.append("Na")
#print(PROTEINA)
    else: 
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h1 property="name">([a-zA-Z0-9].*?)<', html) 
        for link in links:
            nuevo=link.decode()
            PROTEINA1 = PROTEINA1+[nuevo]
            
print(PROTEINA1)
len(PROTEINA1)
# Out:
# ['High affinity immunoglobulin epsilon receptor subunit gamma', 'Na', 'Testis expressed 33', 'Thiosulfate sulfurtransferase', 'Sulfurtransferase', 'Potassium channel tetramerization domain containing 17', 'Transmembrane serine protease 6', 'Interleukin-15', 'Na', 'C1q and TNF related 6', 'Na', 'Somatostatin receptor type 2', 'Ras-related C3 botulinum toxin substrate 2', 'Na', 'ADP-ribosylation factor-like protein 4A', 'Extracellular leucine rich repeat and fibronectin type III domain containing 2', 'Beta-1,3-N-acetylglucosaminyltransferase', 'Caspase recruitment domain family member 10', 'Na', 'Na', 'Ubiquitin carboxyl-terminal hydrolase', 'Potassium voltage-gated channel subfamily H member 1', 'Multifunctional fusion protein', 'MANSC domain containing 4', '28S ribosomal protein S35, mitochondrial', 'Na', 'Ras-related protein Rab-15', 'Protein S100-A4', 'Chromosome 5 C12orf71 homolog', 'Na', 'Single-pass membrane protein with coiled-coil domains 2', 'Na', 'Class E basic helix-loop-helix protein 40']
# 33

# %%
###########################################
# COLUMNA4 PROTEIN  
###########################################
PROTEINA2=[]

for i in urls[33:34]:
    #print(i)
    if i==0:
        PROTEINA2.append("Na")
#print(PROTEINA)
    else: 
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h1 property="name">(.[a-zA-Z0-9].*?)<', html) 
        for link in links:
            nuevo=link.decode()
            PROTEINA2 = PROTEINA2+[nuevo]
            
print(PROTEINA2)
len(PROTEINA2)
# Out:
# ['[F-actin]-monooxygenase MICAL1']
# 1

# %%
###########################################
# COLUMNA4 PROTEIN  
###########################################

PROTEINA3=[]

for i in urls[34:200]:
    #print(i)
    if i==0:
        PROTEINA3.append("Na")
#print(PROTEINA)
    else: 
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h1 property="name">([a-zA-Z0-9].*?)<', html) 
        for link in links:
            nuevo=link.decode()
            PROTEINA3 = PROTEINA3+[nuevo]
            
print(PROTEINA3)
len(PROTEINA3)
# Out:
# ['Elongation of very long chain fatty acids protein 1', 'DUF4203 domain-containing protein', 'FGFR1 oncogene partner 2', 'Chromosome 12 open reading frame 11 ortholog', 'Na', 'Na', 'Inositol 1,4,5-trisphosphate receptor type 2', 'Sarcospan', 'Na', 'Class E basic helix-loop-helix protein 40', 'Na', 'Na', 'LTD domain-containing protein', 'Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform', 'Na', 'Acyl carrier protein, mitochondrial', 'Dynein intermediate chain CFAP94, axonemal', 'Na', 'Na', 'Branched-chain-amino-acid aminotransferase', 'Na', 'SRY-box transcription factor 5', 'Ethanolamine kinase 1', 'C2 domain-containing protein', 'Alpha-N-acetylneuraminide alpha-2,8-sialyltransferase', 'Na', 'Na', 'N-acylneuraminate cytidylyltransferase', 'ATP binding cassette subfamily C member 9', 'Potassium inwardly rectifying channel subfamily J member 8', 'Glycogen [starch] synthase', 'Spexin', 'Vesicle transport protein GOT1B', 'DNA repair protein RAD51 homolog 1', 'Pyridine nucleotide-disulfide oxidoreductase domain-containing protein 1', 'Solute carrier organic anion transporter family member', 'Insulin-degrading enzyme', 'Solute carrier organic anion transporter family member', 'Na', 'Na', 'Solute carrier organic anion transporter family member', 'Brefeldin A-inhibited guanine nucleotide-exchange protein 1', 'LIM domain only protein 3', 'Na', 'Microsomal glutathione S-transferase 1', 'Solute carrier family 15 member 5', 'Y-box-binding protein 1', 'Na', 'Cellular tumor antigen p53', 'Na', 'Epidermal growth factor receptor pathway substrate 8', 'Tyrosine-protein kinase Fyn', 'Ras-related and estrogen-regulated growth inhibitor', 'Na', "Retinal cone rhodopsin-sensitive cGMP 3',5'-cyclic phosphodiesterase subunit gamma", 'Transforming protein RhoA', 'Endoplasmic reticulum resident protein 27', 'Lactadherin', 'NAD(P)(+)--arginine ADP-ribosyltransferase', 'Single-pass membrane protein with coiled-coil domains 3', 'Chromosome 5 C12orf60 homolog', 'Polyglutamine-binding protein 1', 'Na', 'Na', 'Guanylate cyclase', 'Phospholipase B-like 1', 'Na', 'Na', 'General transcription and DNA repair factor IIH helicase subunit XPB', 'Na', 'Na', 'C-C motif chemokine 2', 'Taste receptor type 2', 'Na', 'Y-box binding protein 3', 'Eukaryotic initiation factor 4A-III', 'NK receptor Ly49', 'Na', 'Na', 'C-type lectin domain-containing protein', 'Na', 'C-type lectin domain-containing protein', 'Na', 'Natural killer cells antigen CD94', 'Na', 'Na', 'C-type lectin domain-containing protein', 'Na', 'Killer cell lectin-like receptor subfamily C1 member 2', 'Na', 'Killer cell lectin-like receptor family J member 1', 'C-type lectin domain-containing protein', 'C-type lectin domain-containing protein', 'Killer cell lectin-like receptor subfamily C1 member 2', 'C-type lectin domain-containing protein', 'Na', 'Hematopoietic cell signal transducer', 'Natural killer cells antigen CD94', 'C-type lectin domain-containing protein', 'C-type lectin domain-containing protein', 'Gamma-aminobutyric acid receptor-associated protein-like 1', 'LOC618567 protein', 'Oxidized low-density lipoprotein receptor 1', 'C-type lectin domain family 7 member A', 'C-type lectin domain family 1 member A', 'C-type lectin domain-containing protein', 'Receptor of activated protein C kinase 1', 'C-type lectin domain family 12 member B', 'C-type lectin domain family 12 member B', 'Uncharacterized protein', 'Na', 'Na', 'Killer cell lectin like receptor F2', 'C-type lectin domain-containing protein', 'C-type lectin domain-containing protein', 'C-type lectin domain-containing protein', 'C-type lectin domain-containing protein', 'Na', 'Na', 'KLRF1 protein', 'Na', 'Transmembrane protein 106A', 'C-type lectin domain-containing protein', 'Na', 'Na', 'C-type lectin domain-containing protein', 'Na', 'Na', 'Na', 'Na', 'Uncharacterized protein', 'Na', 'Uncharacterized protein', 'Uncharacterized protein', 'SHC-transforming protein 1', 'Uncharacterized protein', 'Uncharacterized protein ...
# 166

# %%
PROTEINA = PROTEINA1 + PROTEINA2+ PROTEINA3
len(PROTEINA)
# Out:
# 200

# %%
########################################
# COLUMNA5 GENES 
########################################

GENES=[]

for i in urls:
    if i==0:
        GENES.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<h2>([A-Z].*?)<', html) 
        #print(links)
        if len(re.findall(b'<h2>([A-Z].*?)<', html))==1:  # Algunos Entrys no tienen el nombre de Gene, por lo tanto links saldría vacío, con len =0
            for link in links:
                nuevo=link.decode()
                GENES=GENES+[nuevo]
        else:
        
            GENES=GENES+["N/A"]
print(GENES)
len(GENES)
# Out:
# ['FCER1G', 'Na', 'TEX33', 'TST', 'MPST', 'KCTD17', 'TMPRSS6', 'IL15', 'Na', 'C1QTNF6', 'Na', 'SSTR2', 'RAC2', 'Na', 'ARL4A', 'ELFN2', 'MFNG', 'CARD10', 'Na', 'Na', 'USP18', 'KCNH1', 'KATNAL1', 'MANSC4', 'MRPS35', 'Na', 'RAB15', 'S100A4', 'C5H12orf71', 'Na', 'SMCO2', 'Na', 'BHLHE40', 'MICAL1', 'ELOVL1', 'TM7SF3', 'FGFR1OP2', 'INTS13', 'Na', 'Na', 'ITPR2', 'SSPN', 'Na', 'BHLHE40', 'Na', 'Na', 'LMNTD1', 'PIK3CA', 'Na', 'NDUFAB1', 'CFAP94', 'Na', 'Na', 'BCAT1', 'Na', 'SOX5', 'ETNK1', 'C2CD5', 'ST8SIA1', 'Na', 'Na', 'CMAS', 'ABCC9', 'KCNJ8', 'GYS2', 'SPX', 'GOLT1B', 'RAD51', 'PYROXD1', 'SLCO1A2', 'IDE', 'SLCO1B3', 'Na', 'Na', 'SLCO1C1', 'ARFGEF1', 'LMO3', 'Na', 'MGST1', 'SLC15A5', 'YBX1', 'Na', 'TP53', 'Na', 'EPS8', 'FYN', 'RERG', 'Na', 'PDE6H', 'RHOA', 'ERP27', 'MFGE8', 'ART4', 'SMCO3', 'C5H12orf60', 'PQBP1', 'Na', 'Na', 'GUCY2C', 'PLBD1', 'Na', 'Na', 'ERCC3', 'Na', 'Na', 'CCL2', 'TAS2R8', 'Na', 'YBX3', 'EIF4A3', 'KLRA1', 'Na', 'Na', 'LOC513869', 'Na', 'LOC100140174', 'Na', 'KLRD1', 'Na', 'Na', 'LOC100847738', 'Na', 'NKG2A', 'Na', 'KLRJ1', 'LOC100296778', 'LOC101905403', 'NKG2A', 'NKG2C', 'Na', 'HCST', 'KLRD1', 'LOC618565', 'LOC100848575', 'GABARAPL1', 'TMEM52B', 'OLR1', 'CLEC7A', 'CLEC1A', 'CLEC9A', 'RACK1', 'CLEC12B', 'CLEC12B', 'LOC785168', 'Na', 'Na', 'KLRF2', 'CLEC2B', 'LOC617565', 'LOC509972', 'LOC784451', 'Na', 'Na', 'KLRF1', 'Na', 'TMEM106A', 'LOC100294723', 'Na', 'Na', 'LOC100297676', 'Na', 'Na', 'Na', 'Na', 'OVOS2', 'Na', 'LOC506828', 'WC1.3', 'SHC1', 'WC1-8', 'CD163L1', 'PEX5', 'CLSTN3', 'RBP5', 'C1RL', 'N/A', 'C1S', 'LPCAT3', 'EMG1', 'PHB2', 'Na', 'Na', 'PTPN6', 'Na', 'PQBP1', 'ENO2', 'LRRC23', 'MET', 'TPI1', 'USP5', 'CDCA3', 'GNAT3', 'GPR162', 'CD4', 'ADAM10', 'PTMS', 'MLF2', 'ID3', 'PIANP', 'ZNF384']
# 200

# %%
len(urls)
# Out:
# 200

# %%
################################
# COLUMNA6 ORGANISMO 
################################

ORGANISMO=[]

for i in urls:
    if i==0:
        ORGANISMO.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<em>([A-Z].*?)</em>', html) 
        if  len(links)==2:     # si hay más de un objeto en links o si hay exactamente 2.
            ORGANISMO=ORGANISMO+ [links[1]]   #agrega  a la lista solo el segundo objeto de la lista
        else:
            for link in links:
                nuevo=link.decode()
                ORGANISMO=ORGANISMO+[nuevo]
print(ORGANISMO)
len(ORGANISMO)
# Out:
# ['Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Na', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', b'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Na', 'Na', 'Bos taurus (Bovine)', 'Na', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Bos indicus x Bos taurus (Hybrid cattle)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)', 'Bos taurus (Bovine)']
# 200

# %%
################################
# COLUMNA7 STATUS  
################################

STATUS=[]

for i in urls:
    if i==0:
        STATUS.append("Na")
    else:        
        url = i
        html = urllib.request.urlopen(url, context=ctx).read()  
        links = re.findall(b'<span>([UR].*viewed)', html) 
        for link in links:
            nuevo=link.decode()
            STATUS=STATUS+[nuevo]
print(STATUS)
len(STATUS)
# Out:
# ['Reviewed', 'Na', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Reviewed', 'Unreviewed', 'Na', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Reviewed', 'Reviewed', 'Na', 'Reviewed', 'Unreviewed', 'Reviewed', 'Na', 'Reviewed', 'Na', 'Unreviewed', 'Reviewed', 'Reviewed', 'Na', 'Reviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Na', 'Na', 'Reviewed', 'Unreviewed', 'Na', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Reviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Unreviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Na', 'Na', 'Na', 'Unreviewed', 'Na', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Na', 'Na', 'Unreviewed', 'Na', 'Reviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Unreviewed', 'Reviewed', 'Reviewed', 'Unreviewed', 'Reviewed', 'Unreviewed', 'Unreviewed']
# 200

# %%
################################
# COLUMNA8 GO - Biological process  
################################

GO_Biological_process = []

for i in urls:
    if i==0:
        GO_Biological_process.append("Na")
    else:
        uclient=urlopen(i)
        pagehtml=uclient.read()
        uclient.close()                                    
        pagesoup=soup(pagehtml, "html.parser")
        page=pagesoup.find("ul",{"class":"noNumbering biological_process"}) 
        
        if page==None:
            GO_Biological_process.append("Na")
        else:
            location=page.find_all("a",{"onclick":"window.ga('UniProt-Entry-View', 'click', 'Display-GO-Term');"})
            #print(location)
            cadena = ""
            for i in range(0,len(location)):
                if location[i].text=="":
                    cadena = cadena + "-"
                else:
                    #GO_Biological_process.append(location[i].text)
                    cadena = cadena + location[i].text + "."
                #print(type(location[i].text))

            GO_Biological_process.append(cadena)

print(GO_Biological_process)
len(GO_Biological_process)
# Out:
# ['antigen processing and presentation of exogenous peptide antigen via MHC class I.antigen processing and presentation of exogenous peptide antigen via MHC class II.cellular response to low-density lipoprotein particle stimulus.defense response to bacterium.Fc-gamma receptor signaling pathway.Fc receptor mediated stimulatory signaling pathway.immunoglobulin mediated immune response.innate immune response.interleukin-3-mediated signaling pathway.neutrophil activation involved in immune response.neutrophil chemotaxis.positive regulation of interleukin-4 production.positive regulation of phagocytosis.receptor internalization.regulation of platelet activation.T cell differentiation involved in immune response.', 'Na', 'Na', 'rRNA import into mitochondrion.rRNA transport.transsulfuration.', 'transsulfuration.', 'endoplasmic reticulum calcium ion homeostasis.positive regulation of cilium assembly.proteasome-mediated ubiquitin-dependent protein catabolic process.protein homooligomerization.', 'cellular iron ion homeostasis.iron ion homeostasis.membrane protein proteolysis.negative regulation of BMP signaling pathway.negative regulation of transcription by RNA polymerase II.positive regulation of transcription by RNA polymerase II.self proteolysis.', 'cell maturation.extrathymic T cell selection.immune response.interleukin-15-mediated signaling pathway.lymph node development.macrophage differentiation.negative regulation of cold-induced thermogenesis.neutrophil activation.NK T cell proliferation.positive regulation of cytokine production.positive regulation of immune response.positive regulation of interleukin-17 production.positive regulation of natural killer cell differentiation.positive regulation of natural killer cell proliferation.positive regulation of peptidyl-tyrosine phosphorylation.positive regulation of phagocytosis.positive regulation of protein O-linked glycosylation.positive regulation of T cell proliferation.positive regulation of tyrosine phosphorylation of STAT protein.regulation of defense response to virus by host.regulation of T cell differentiation.tyrosine phosphorylation of STAT protein.', 'Na', 'Na', 'Na', 'Na', 'actin filament organization.cell projection assembly.cortical cytoskeleton organization.engulfment of apoptotic cell.establishment or maintenance of cell polarity.G protein-coupled receptor signaling pathway.lymphocyte aggregation.motor neuron axon guidance.positive regulation of cell population proliferation.positive regulation of lamellipodium assembly.positive regulation of neutrophil chemotaxis.Rac protein signal transduction.regulation of actin cytoskeleton organization.regulation of cell shape.regulation of cell-substrate adhesion.regulation of mast cell chemotaxis.regulation of mast cell degranulation.regulation of neutrophil migration.regulation of respiratory burst.regulation of T cell proliferation.', 'Na', 'brown fat cell differentiation.intracellular protein transport.vesicle-mediated transport.', 'negative regulation of phosphatase activity.', 'blastocyst formation.marginal zone B cell differentiation.pattern specification process.positive regulation of Notch signaling pathway.positive regulation of protein binding.regulation of Notch signaling pathway.', 'activation of NF-kappaB-inducing kinase activity.negative regulation of cell migration involved in sprouting angiogenesis.positive regulation of protein localization to nucleus.regulation of apoptotic process.', 'Na', 'Na', 'protein deubiquitination.ubiquitin-dependent protein catabolic process.', 'cellular response to calcium ion.phosphatidylinositol-mediated signaling.potassium ion transmembrane transport.regulation of cell population proliferation.regulation of ion transmembrane transport.regulation of membrane potential.', 'cell cycle.cell division.cytoplasmic microtubule organization.microtubule severing.spermatogenesis.', 'Na', 'mitochondrial translation.', 'Na', 'cellular response to insulin stimulus.protein localization to plas ...
# 200

# %%
GO_Biological_process[1]
# Out:
# 'Na'

# %%
import pandas as pd
##Guardando un archivo de formato data frame
#Creamos un diccionario data
data = {'Gen abrev': LISTA_GENES,
        'Entry': LISTA_ENTRY,
        'Entry name': LISTA_ENTRYNAME,
        'Protein' : PROTEINA,
        'Gene': GENES,
        'Organism' : ORGANISMO,
        'Status': STATUS,
        'GO-Biological process': GO_Biological_process}
# Luego creamos un dataframe y especificamos las columnas.
df = pd.DataFrame(data, columns = ['Gen abrev','Entry','Entry name','Protein','Gene','Organism','Status', 'GO-Biological process'])

df
# Out:
#      Gen abrev       Entry        Entry name  \
# 0       CSF2RB      Q9BDR7       FCERG_BOVIN
# 1    LOC788541          Na                Na
# 2        TEX33      Q32LI7      Q32LI7_BOVIN
# 3          TST      P00586        THTR_BOVIN
# 4         MPST  A0A3Q1M9D2  A0A3Q1M9D2_BOVIN
# ..         ...         ...               ...
# 195       PTMS      P08814        PTMS_BOVIN
# 196       MLF2      F1MYV8      F1MYV8_BOVIN
# 197     COPS7A      Q5E981         ID3_BOVIN
# 198      PIANP      A4IFJ4      A4IFJ4_BOVIN
# 199     ZNF384  A0A3Q1M8T6  A0A3Q1M8T6_BOVIN
#
#                                                Protein    Gene  \
# 0    High affinity immunoglobulin epsilon receptor ...  FCER1G
# 1                                                   Na      Na
# 2                                  Testis expressed 33   TEX33
# 3                        Thiosulfate sulfurtransferase     TST
# 4                                    Sulfurtransferase    MPST
# ..                                                 ...     ...
# 195                                       Parathymosin    PTMS
# 196                            Uncharacterized protein    MLF2
# 197                 DNA-binding protein inhibitor ID-3     ID3
# 198                                 C5H12ORF53 protein   PIANP
# 199                            Zinc finger protein 384  ZNF384
#
#                 Organism      Status  \
# 0    Bos taurus (Bovine)    Reviewed
# 1                     Na          Na
# 2    Bos taurus (Bovine)  Unreviewed
# 3    Bos taurus (Bovine)    Reviewed
# 4    Bos taurus (Bovine)  Unreviewed
# ..                   ...         ...
# 195  Bos taurus (Bovine)    Reviewed
# 196  Bos taurus (Bovine)  Unreviewed
# 197  Bos taurus (Bovine)    Reviewed
# 198  Bos taurus (Bovine)  Unreviewed
# 199  Bos taurus (Bovine)  Unreviewed
#
#                                  GO-Biological process
# 0    antigen processing and presentation of exogeno...
# 1                                                   Na
# 2                                                   Na
# 3    rRNA import into mitochondrion.rRNA transport....
# 4                                    transsulfuration.
# ..                                                 ...
# 195                             immune system process.
# 196        regulation of transcription, DNA-templated.
# 197  cell differentiation.cellular response to lept...
# 198                     regulation of immune response.
# 199  regulation of transcription by RNA polymerase II.
#
# [200 rows x 8 columns]

# %%
#### creación del excel
from pandas import ExcelWriter
writer = ExcelWriter('./Parte3.xlsx')
df.to_excel(writer, index=False)
writer.save()
